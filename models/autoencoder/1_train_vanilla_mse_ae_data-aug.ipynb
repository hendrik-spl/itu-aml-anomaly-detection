# %%
# !pip3 install -r ../../requirements.txt
# Out:
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.12/site-packages (from -r ../../requirements.txt (line 1)) (6.29.5)
# Requirement already satisfied: matplotlib==3.9.2 in /opt/conda/lib/python3.12/site-packages (from -r ../../requirements.txt (line 2)) (3.9.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.12/site-packages (from -r ../../requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: opencv-python==4.10.0.84 in /opt/conda/lib/python3.12/site-packages (from -r ../../requirements.txt (line 4)) (4.10.0.84)
# Requirement already satisfied: pandas==2.2.3 in /opt/conda/lib/python3.12/site-packages (from -r ../../requirements.txt (line 5)) (2.2.3)
# Requirement already satisfied: scikit-learn==1.5.2 in /opt/conda/lib/python3.12/site-packages (from -r ../../requirements.txt (line 6)) (1.5.2)
# Requirement already satisfied: seaborn==0.13.2 in /opt/conda/lib/python3.12/site-packages (from -r ../../requirements.txt (line 7)) (0.13.2)
# Requirement already satisfied: tensorflow==2.18.0 in /opt/conda/lib/python3.12/site-packages (from -r ../../requirements.txt (line 8)) (2.18.0)
# Requirement already satisfied: tqdm==4.67.0 in /opt/conda/lib/python3.12/site-packages (from -r ../../requirements.txt (line 9)) (4.67.0)
# Requirement already satisfied: wandb==0.18.6 in /opt/conda/lib/python3.12/site-packages (from -r ../../requirements.txt (line 10)) (0.18.6)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../../requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../../requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../../requirements.txt (line 2)) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../../requirements.txt (line 2)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../../requirements.txt (line 2)) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../../requirements.txt (line 2)) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../../requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../../requirements.txt (line 2)) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.3->-r ../../requirements.txt (line 5)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.3->-r ../../requirements.txt (line 5)) (2024.2)
# Requirement already satisfied: scipy>=1.6.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn==1.5.2->-r ../../requirements.txt (line 6)) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn==1.5.2->-r ../../requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn==1.5.2->-r ../../requirements.txt (line 6)) (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (5.29.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (75.3.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (1.68.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (3.7.0)
# Requirement already satisfied: h5py>=3.11.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (0.4.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.12/site-packages (from wandb==0.18.6->-r ../../requirements.txt (line 10)) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from wandb==0.18.6->-r ../../requirements.txt (line 10)) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from wandb==0.18.6->-r ../../requirements.txt (line 10)) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.12/site-packages (from wandb==0.18.6->-r ../../requirements.txt (line 10)) (4.3.6)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.12/site-packages (from wandb==0.18.6->-r ../../requirements.txt (line 10)) (6.1.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.12/site-packages (from wandb==0.18.6->-r ../../requirements.txt (line 10)) (6.0.2)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from wandb==0.18.6->-r ../../requirements.txt (line 10)) (2.19.2)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.12/site-packages (from wandb==0.18.6->-r ../../requirements.txt (line 10)) (1.3.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->-r ../../requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.12/site-packages (from ipykernel->-r ../../requirements.txt (line 1)) (1.8.8)
# Requirement already satisfied: ipython>=7.23.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->-r ../../requirements.txt (line 1)) (8.29.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.12/site-packages (from ipykernel->-r ../../requirements.txt (line 1)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.12/site-packages (from ipykernel->-r ../../requirements.txt (line 1)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->-r ../../requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.12/site-packages (from ipykernel->-r ../../requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.12/site-packages (from ipykernel->-r ../../requirements.txt (line 1)) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->-r ../../requirements.txt (line 1)) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/conda/lib/python3.12/site-packages (from ipykernel->-r ../../requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (0.45.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.12/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb==0.18.6->-r ../../requirements.txt (line 10)) (4.0.11)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (2.18.0)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: rich in /opt/conda/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (13.9.4)
# Requirement already satisfied: namex in /opt/conda/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (0.0.8)
# Requirement already satisfied: optree in /opt/conda/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (3.1.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb==0.18.6->-r ../../requirements.txt (line 10)) (5.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/conda/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (0.1.2)

# %%
import os
import sys

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose, LeakyReLU, BatchNormalization, Flatten, Dense, Reshape, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import wandb
from wandb.integration.keras import WandbMetricsLogger, WandbModelCheckpoint

# modify sys.path for it to contain the main repo path so we can import modules such as below
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '../..'))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

from utils.helper import get_root_dir, set_seed, setup_gpu
from utils.data import load_data_with_test_split
from utils.plots import plot_reconstructions, plot_history
from utils.latent_space import plot_latent_space
from utils.evaluation import evaluate_autoencoder, ssim_loss, ssim_l1_loss, dssim_loss, evaluate_autoencoder_with_distribution_threshold, evaluate_autoencoder_with_threshold_generator

# %%
# Hyperparameter to tune
config = {
    "comment" : "run with data augmentation",
    "epochs" : 100,
    "loss" : 'mse',
    "optimizer" : "adam",
    "dropout": True,
    "dropout_value" : 0.0,
    "rotation_range" : 90,
    "batch_size" : 16,
    "latent_dim" : 512,
    "threshold_percentage" : 80,
    "data_class" : "screw",
    "model_type" : "autoencoder"
}

# Rather static parameters, no need to track
IMAGE_SIZE = (256, 256)
INPUT_SHAPE = IMAGE_SIZE + (3,)

# %%
wandb.init(project="autoencoder", config=config)
config = wandb.config # this turns our hyperparameter config into a proper object with attributes
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: hendrik-spl (itu-aml-project). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>/work/itu-aml-anomaly-detection/models/autoencoder/wandb/run-20241210_144627-qumot9xl</code>
# Syncing run <strong><a href='https://wandb.ai/itu-aml-project/autoencoder/runs/qumot9xl' target="_blank">kind-blaze-7</a></strong> to <a href='https://wandb.ai/itu-aml-project/autoencoder' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/itu-aml-project/autoencoder' target="_blank">https://wandb.ai/itu-aml-project/autoencoder</a>
#  View run at <a href='https://wandb.ai/itu-aml-project/autoencoder/runs/qumot9xl' target="_blank">https://wandb.ai/itu-aml-project/autoencoder/runs/qumot9xl</a>

# %%
root_dir = get_root_dir()
# root_dir = 'Mini Project'

set_seed(1234)

model_dir = os.path.join(root_dir, 'models', config.model_type)

cpkt_path = os.path.join(model_dir, 'logs', 'checkpoints', f'{config.comment}_checkpoint.model.keras')
weights_path = os.path.join(model_dir, 'logs', 'weights', f'{config.comment}_model.keras')
assert not os.path.exists(weights_path), f'Path already exists: {weights_path}. Please change the comment.'

# %%
train_generator, validation_generator, test_generator, threshold_generator = load_data_with_test_split(
    category="screw",
    batch_size=32,
    test_split=0.4,
    rotation_range=config.rotation_range
)
# Out:
# Found 256 images belonging to 1 classes.
# Found 64 images belonging to 1 classes.
# Found 98 images belonging to 6 classes.
# Found 62 images belonging to 6 classes.

# %%
def vanilla_autoencoder(input_shape=INPUT_SHAPE, optimizer='', latent_dim=512, loss='mse'):
    """
        input_shape (tuple): Shape of the input images (height, width, channels).
        latent_dim (int): Dimension of the latent space.
        loss (str): Loss used to train the autoencoder. Options: 'mse', 'ssim', etc.
    """
    # Encoder
    input_img = Input(shape=input_shape)

    # Encoder with reduced complexity
    x = Conv2D(32, (3, 3), padding='same')(input_img)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = MaxPooling2D((2, 2), padding='same')(x)  # (128, 128, 32)
    x = Dropout(0.3)(x)

    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = MaxPooling2D((2, 2), padding='same')(x)  # (64, 64, 64)
    x = Dropout(0.3)(x)

    x = Conv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = MaxPooling2D((2, 2), padding='same')(x)  # (32, 32, 128)
    x = Dropout(0.3)(x)

    # Bottleneck
    x = Flatten()(x)  # Flattened Shape: (32 * 32 * 128,)
    encoded = Dense(latent_dim)(x)  # Latent space size reduced to 526
    encoded = BatchNormalization()(encoded)
    encoded = LeakyReLU(name='bottleneck')(encoded)

    # Decoder with reduced complexity
    x = Dense(32 * 32 * 128)(encoded)
    x = Reshape((32, 32, 128))(x)

    x = UpSampling2D((2, 2))(x)  # (64, 64, 128)
    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = UpSampling2D((2, 2))(x)  # (128, 128, 64)
    x = Conv2D(32, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = UpSampling2D((2, 2))(x)  # (256, 256, 32)
    x = Conv2D(input_shape[2], (3, 3), activation='sigmoid', padding='same')(x)

    # Autoencoder Model
    autoencoder = Model(input_img, x)
    autoencoder.compile(optimizer=optimizer, loss=loss)
    return autoencoder

# get correct loss from config as functions are not callable from config itself
if config.loss == 'mae': loss = 'mae'
elif config.loss == 'mse': loss = 'mse'
elif config.loss == 'dssim_loss': loss = dssim_loss
elif config.loss == 'ssim_loss': loss = ssim_loss
elif config.loss == 'ssim_l1_loss': loss = ssim_l1_loss
else:
    raise ValueError(f"Unknown loss function: {config.loss}. Please define a function to calculate the error.")

print(f"Used Loss to train:{loss}")
print(f"Optimizer: {config.optimizer}")

autoencoder = vanilla_autoencoder(
    input_shape=INPUT_SHAPE, 
    optimizer=config.optimizer, 
    latent_dim=config.latent_dim, 
    loss=loss
)

print("Input shape:", autoencoder.input_shape)
print("Output shape:", autoencoder.output_shape)

autoencoder.summary()
# Out:
# Used Loss to train:mse
# Optimizer: adam
# Input shape: (None, 256, 256, 3)
# Output shape: (None, 256, 256, 3)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256, 256, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 256, 256, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 128, 128, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128, 128, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 131072)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    67,109,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bottleneck (LeakyReLU)          │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 131072)         │    67,239,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 64, 64, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 128, 128, 32)   │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_2 (UpSampling2D)  │ (None, 256, 256, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 256, 256, 3)    │           867 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 134,539,011 (513.23 MB)
#  Trainable params: 134,537,347 (513.22 MB)
#  Non-trainable params: 1,664 (6.50 KB)

# %%
#define early stopping and checkpoints
early_stop = EarlyStopping(
    monitor="val_loss", 
    mode="min",
    patience=20, 
    start_from_epoch=20
    )

checkpoint = ModelCheckpoint(
    cpkt_path, 
    monitor="val_loss", 
    mode="min", 
    save_best_only=True, 
    verbose=1
    )

history = autoencoder.fit(
    train_generator,
    epochs=config.epochs,
    validation_data=validation_generator,
    callbacks=[
        early_stop,
        checkpoint,
        WandbMetricsLogger(),
        # WandbModelCheckpoint("models"), # Saves model checkpoint to W&B
    ],
)

wandb.finish()
# Out:
# /opt/conda/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0932
# Epoch 1: val_loss improved from inf to 0.04790, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - loss: 0.0898 - val_loss: 0.0479
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0190
# Epoch 2: val_loss improved from 0.04790 to 0.03938, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0186 - val_loss: 0.0394
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0101
# Epoch 3: val_loss improved from 0.03938 to 0.02603, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0100 - val_loss: 0.0260
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0073
# Epoch 4: val_loss improved from 0.02603 to 0.02568, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0072 - val_loss: 0.0257
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0054
# Epoch 5: val_loss did not improve from 0.02568
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0053 - val_loss: 0.0338
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0045
# Epoch 6: val_loss did not improve from 0.02568
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0044 - val_loss: 0.0292
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0036
# Epoch 7: val_loss did not improve from 0.02568
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0036 - val_loss: 0.0266
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0034
# Epoch 8: val_loss improved from 0.02568 to 0.02173, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0033 - val_loss: 0.0217
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0032
# Epoch 9: val_loss improved from 0.02173 to 0.02115, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0032 - val_loss: 0.0212
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0031
# Epoch 10: val_loss improved from 0.02115 to 0.01916, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0031 - val_loss: 0.0192
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0028
# Epoch 11: val_loss did not improve from 0.01916
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0028 - val_loss: 0.0200
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0027
# Epoch 12: val_loss did not improve from 0.01916
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0027 - val_loss: 0.0195
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0026
# Epoch 13: val_loss did not improve from 0.01916
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0026 - val_loss: 0.0192
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0024
# Epoch 14: val_loss improved from 0.01916 to 0.01844, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0024 - val_loss: 0.0184
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0024
# Epoch 15: val_loss improved from 0.01844 to 0.01797, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0024 - val_loss: 0.0180
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0025
# Epoch 16: val_loss did not improve from 0.01797
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0025 - val_loss: 0.0182
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0024
# Epoch 17: val_loss improved from 0.01797 to 0.01729, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0024 - val_loss: 0.0173
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0024
# Epoch 18: val_loss did not improve from 0.01729
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0024 - val_loss: 0.0174
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0023
# Epoch 19: val_loss improved from 0.01729 to 0.01655, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0023 - val_loss: 0.0165
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0022
# Epoch 20: val_loss improved from 0.01655 to 0.01644, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0022 - val_loss: 0.0164
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0022
# Epoch 21: val_loss improved from 0.01644 to 0.01611, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0022 - val_loss: 0.0161
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0021
# Epoch 22: val_loss did not improve from 0.01611
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0021 - val_loss: 0.0162
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0021
# Epoch 23: val_loss improved from 0.01611 to 0.01520, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0021 - val_loss: 0.0152
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0020
# Epoch 24: val_loss did not improve from 0.01520
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0020 - val_loss: 0.0155
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0020
# Epoch 25: val_loss improved from 0.01520 to 0.01482, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0020 - val_loss: 0.0148
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0020
# Epoch 26: val_loss did not improve from 0.01482
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0020 - val_loss: 0.0150
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0020
# Epoch 27: val_loss improved from 0.01482 to 0.01440, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0020 - val_loss: 0.0144
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0018
# Epoch 28: val_loss improved from 0.01440 to 0.01404, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0018 - val_loss: 0.0140
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0020
# Epoch 29: val_loss improved from 0.01404 to 0.01402, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0020 - val_loss: 0.0140
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0019
# Epoch 30: val_loss improved from 0.01402 to 0.01356, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0019 - val_loss: 0.0136
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0019
# Epoch 31: val_loss improved from 0.01356 to 0.01305, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0019 - val_loss: 0.0131
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0018
# Epoch 32: val_loss improved from 0.01305 to 0.01257, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0018 - val_loss: 0.0126
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0018
# Epoch 33: val_loss improved from 0.01257 to 0.01247, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0018 - val_loss: 0.0125
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0018
# Epoch 34: val_loss improved from 0.01247 to 0.01200, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0018 - val_loss: 0.0120
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0018
# Epoch 35: val_loss improved from 0.01200 to 0.01161, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0018 - val_loss: 0.0116
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0018
# Epoch 36: val_loss improved from 0.01161 to 0.01106, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0018 - val_loss: 0.0111
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0017
# Epoch 37: val_loss improved from 0.01106 to 0.01066, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0017 - val_loss: 0.0107
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0017
# Epoch 38: val_loss improved from 0.01066 to 0.01020, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0017 - val_loss: 0.0102
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0017
# Epoch 39: val_loss did not improve from 0.01020
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0017 - val_loss: 0.0107
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0017
# Epoch 40: val_loss improved from 0.01020 to 0.01011, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0017 - val_loss: 0.0101
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0017
# Epoch 41: val_loss improved from 0.01011 to 0.00966, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0017 - val_loss: 0.0097
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0016
# Epoch 42: val_loss improved from 0.00966 to 0.00930, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0016 - val_loss: 0.0093
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0017
# Epoch 43: val_loss did not improve from 0.00930
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0017 - val_loss: 0.0096
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0018
# Epoch 44: val_loss improved from 0.00930 to 0.00886, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0018 - val_loss: 0.0089
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0016
# Epoch 45: val_loss improved from 0.00886 to 0.00849, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0016 - val_loss: 0.0085
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0016
# Epoch 46: val_loss did not improve from 0.00849
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0016 - val_loss: 0.0087
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0016
# Epoch 47: val_loss did not improve from 0.00849
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0016 - val_loss: 0.0089
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0016
# Epoch 48: val_loss improved from 0.00849 to 0.00845, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0016 - val_loss: 0.0084
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0016
# Epoch 49: val_loss improved from 0.00845 to 0.00837, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0016 - val_loss: 0.0084
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0016
# Epoch 50: val_loss improved from 0.00837 to 0.00813, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0016 - val_loss: 0.0081
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0015
# Epoch 51: val_loss improved from 0.00813 to 0.00719, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0015 - val_loss: 0.0072
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0015
# Epoch 52: val_loss did not improve from 0.00719
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0015 - val_loss: 0.0080
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0015
# Epoch 53: val_loss improved from 0.00719 to 0.00701, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0015 - val_loss: 0.0070
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0015
# Epoch 54: val_loss did not improve from 0.00701
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0015 - val_loss: 0.0078
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0015
# Epoch 55: val_loss did not improve from 0.00701
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0015 - val_loss: 0.0070
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0015
# Epoch 56: val_loss did not improve from 0.00701
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0015 - val_loss: 0.0077
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0016
# Epoch 57: val_loss improved from 0.00701 to 0.00679, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0016 - val_loss: 0.0068
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0016
# Epoch 58: val_loss improved from 0.00679 to 0.00662, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0016 - val_loss: 0.0066
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0015
# Epoch 59: val_loss did not improve from 0.00662
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0015 - val_loss: 0.0073
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0015
# Epoch 60: val_loss did not improve from 0.00662
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0015 - val_loss: 0.0067
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0015
# Epoch 61: val_loss improved from 0.00662 to 0.00567, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0015 - val_loss: 0.0057
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0015
# Epoch 62: val_loss did not improve from 0.00567
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0015 - val_loss: 0.0064
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 63: val_loss did not improve from 0.00567
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0014 - val_loss: 0.0061
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 64: val_loss did not improve from 0.00567
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0014 - val_loss: 0.0061
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0015
# Epoch 65: val_loss did not improve from 0.00567
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0015 - val_loss: 0.0057
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 66: val_loss did not improve from 0.00567
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0014 - val_loss: 0.0058
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 67: val_loss improved from 0.00567 to 0.00563, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0014 - val_loss: 0.0056
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0015
# Epoch 68: val_loss improved from 0.00563 to 0.00513, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0014 - val_loss: 0.0051
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0015
# Epoch 69: val_loss did not improve from 0.00513
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0015 - val_loss: 0.0052
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 70: val_loss did not improve from 0.00513
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0014 - val_loss: 0.0056
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 71: val_loss improved from 0.00513 to 0.00458, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0014 - val_loss: 0.0046
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 72: val_loss improved from 0.00458 to 0.00405, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0014 - val_loss: 0.0040
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 73: val_loss did not improve from 0.00405
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0014 - val_loss: 0.0050
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 74: val_loss did not improve from 0.00405
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0014 - val_loss: 0.0045
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 75: val_loss did not improve from 0.00405
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0014 - val_loss: 0.0043
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 76: val_loss improved from 0.00405 to 0.00399, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0014 - val_loss: 0.0040
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 77: val_loss did not improve from 0.00399
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0014 - val_loss: 0.0044
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 78: val_loss did not improve from 0.00399
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0014 - val_loss: 0.0045
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 79: val_loss improved from 0.00399 to 0.00398, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0014 - val_loss: 0.0040
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 80: val_loss did not improve from 0.00398
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0014 - val_loss: 0.0041
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 81: val_loss did not improve from 0.00398
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0014 - val_loss: 0.0041
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 82: val_loss improved from 0.00398 to 0.00336, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0013
# Epoch 83: val_loss did not improve from 0.00336
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0013 - val_loss: 0.0039
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 84: val_loss did not improve from 0.00336
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0014 - val_loss: 0.0040
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 85: val_loss did not improve from 0.00336
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0014 - val_loss: 0.0036
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 86: val_loss did not improve from 0.00336
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0014 - val_loss: 0.0043
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 87: val_loss did not improve from 0.00336
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0014 - val_loss: 0.0038
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 88: val_loss did not improve from 0.00336
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0014 - val_loss: 0.0039
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 89: val_loss did not improve from 0.00336
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0013
# Epoch 90: val_loss improved from 0.00336 to 0.00272, saving model to /work/itu-aml-anomaly-detection/models/autoencoder/logs/checkpoints/run with data augmentation_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.0013 - val_loss: 0.0027
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0013
# Epoch 91: val_loss did not improve from 0.00272
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0013 - val_loss: 0.0032
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0013
# Epoch 92: val_loss did not improve from 0.00272
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0013 - val_loss: 0.0040
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0014
# Epoch 93: val_loss did not improve from 0.00272
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0014 - val_loss: 0.0030
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0013
# Epoch 94: val_loss did not improve from 0.00272
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0013 - val_loss: 0.0046
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0013
# Epoch 95: val_loss did not improve from 0.00272
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0013 - val_loss: 0.0034
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0013
# Epoch 96: val_loss did not improve from 0.00272
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0013 - val_loss: 0.0039
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0013
# Epoch 97: val_loss did not improve from 0.00272
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0013 - val_loss: 0.0044
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0013
# Epoch 98: val_loss did not improve from 0.00272
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0013 - val_loss: 0.0030
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0013
# Epoch 99: val_loss did not improve from 0.00272
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0013 - val_loss: 0.0042
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - loss: 0.0013
# Epoch 100: val_loss did not improve from 0.00272
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0013 - val_loss: 0.0029
# VBox(children=(Label(value='0.050 MB of 0.050 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▅▄▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_loss</td><td>█▅▄▄▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>99</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>0.00128</td></tr><tr><td>epoch/val_loss</td><td>0.00294</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">kind-blaze-7</strong> at: <a href='https://wandb.ai/itu-aml-project/autoencoder/runs/qumot9xl' target="_blank">https://wandb.ai/itu-aml-project/autoencoder/runs/qumot9xl</a><br/> View project at: <a href='https://wandb.ai/itu-aml-project/autoencoder' target="_blank">https://wandb.ai/itu-aml-project/autoencoder</a><br/>Synced 4 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241210_144627-qumot9xl/logs</code>

# %%
# plot the training history
plot_history(comment=config.comment, history=history)
# Out:
# Best train_loss: 0.0013
# Best val_loss: 0.0027
# Last improvement of val_loss at epoch: 1

# %%
plot_reconstructions(autoencoder, test_generator, n_images=5, title='Test')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step

# %%
# sampling generated from flow
evaluate_autoencoder_with_threshold_generator(
    autoencoder=autoencoder,
    test_generator=test_generator,
    threshold_generator=threshold_generator,
    config=config
)
# Out:
# Optimal Threshold: 0.0028
#               precision    recall  f1-score   support
#
#       Normal       0.76      0.88      0.81        25
#      Anomaly       0.96      0.90      0.93        73
#
#     accuracy                           0.90        98
#    macro avg       0.86      0.89      0.87        98
# weighted avg       0.91      0.90      0.90        98

# %%
#without threshhold setting via distribution
import importlib
import utils.evaluation

# Reload the module to get updated functions
importlib.reload(utils.evaluation)
from utils.evaluation import evaluate_autoencoder
evaluate_autoencoder(
    config = config,
    autoencoder=autoencoder,
    validation_generator=validation_generator,
    test_generator=test_generator
    )
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.33      1.00      0.49        26
#      Anomaly       1.00      0.25      0.40        72
#
#     accuracy                           0.45        98
#    macro avg       0.66      0.62      0.45        98
# weighted avg       0.82      0.45      0.42        98

# %%
plot_latent_space(autoencoder, test_generator, layer_name='bottleneck')

# %%
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np

def preprocess_image(image_path, target_size=(256, 256)):
    """Load and preprocess an image for the autoencoder."""
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, target_size)
    img = img.astype('float32') / 255.0  # Normalize to [0, 1] and set to float32
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    return img

def calculate_reconstruction_error(original, reconstructed):
    """Calculate the mean squared error between original and reconstructed images."""
    return np.mean((original - reconstructed) ** 2)

def predict_anomaly_and_plot(autoencoder, image_path, mask_dir, threshold=0.02):
    """
    Predict if an image is an anomaly based on reconstruction error
    and plot original, reconstructed, and mask images.
    
    Parameters:
        autoencoder (Model): The trained autoencoder model.
        image_path (str): Path to the image file.
        mask_dir (str): Directory containing anomaly mask images.
        threshold (float): Error threshold to classify as anomaly.
    
    Returns:
        bool: True if anomaly, False otherwise.
        float: The reconstruction error.
    """
    # Preprocess the image
    img = preprocess_image(image_path)
    
    # Reconstruct the image with the autoencoder
    reconstructed_img = autoencoder.predict(img)

    # Ensure reconstructed image is in float32 format
    reconstructed_img = reconstructed_img.astype('float32')
    
    # Calculate reconstruction error
    error = calculate_reconstruction_error(img, reconstructed_img)
    
    # Classify as anomaly if error exceeds the threshold
    is_anomaly = error > threshold

    # Generate the corresponding mask path
    file_name = os.path.basename(image_path).split('.')[0] + '_mask.png'
    label = os.path.basename(os.path.dirname(image_path))
    mask_path = os.path.join(mask_dir, label, file_name)
    
    # Load the mask image if it exists
    if os.path.exists(mask_path):
        mask_img = plt.imread(mask_path)
    else:
        mask_img = None

    # Plot original, reconstructed, and mask images
    plt.figure(figsize=(12, 4))
    
    # Original image
    plt.subplot(1, 3, 1)
    plt.imshow(img[0])  # Remove batch dimension for display
    plt.title("Original Image")
    plt.axis("off")
    
    # Reconstructed image
    plt.subplot(1, 3, 2)
    plt.imshow(reconstructed_img[0])  # Remove batch dimension for display
    plt.title("Reconstructed Image")
    plt.axis("off")
    
    # Anomaly mask
    plt.subplot(1, 3, 3)
    if mask_img is not None:
        plt.imshow(mask_img, cmap="gray")
        plt.title("Anomaly Mask")
    else:
        plt.text(0.5, 0.5, 'No Mask Available', ha='center', va='center', fontsize=12)
    plt.axis("off")
    
    plt.suptitle(f"Reconstruction Error: {error:.4f}| Threshold: {threshold} | Anomaly: {'Yes' if is_anomaly else 'No'}")
    plt.show()
    
    return is_anomaly, error

# Example usage
# Example usage
"""mask_dir = '../../data/screw/ground_truth'
image_paths = [
    '../../data/screw/test/manipulated_front/001.png',
    '../../data/screw/test/scratch_head/001.png', 
    '../../data/screw/test/scratch_neck/001.png' 
]"""
mask_dir = 'data/screw/ground_truth'
image_paths = [
    'data/screw/test/manipulated_front/001.png',
    'data/screw/test/scratch_head/001.png', 
    'data/screw/test/scratch_neck/001.png' 
]
for path in image_paths: 
    is_anomaly, error = predict_anomaly_and_plot(autoencoder, path, mask_dir)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[14], line 104
#      98 image_paths = [
#      99     'data/screw/test/manipulated_front/001.png',
#     100     'data/screw/test/scratch_head/001.png',
#     101     'data/screw/test/scratch_neck/001.png'
#     102 ]
#     103 for path in image_paths:
# --> 104     is_anomaly, error = predict_anomaly_and_plot(autoencoder, path, mask_dir)
#
# Cell In[14], line 35, in predict_anomaly_and_plot(autoencoder, image_path, mask_dir, threshold)
#      20 """
#      21 Predict if an image is an anomaly based on reconstruction error
#      22 and plot original, reconstructed, and mask images.
#    (...)
#      32     float: The reconstruction error.
#      33 """
#      34 # Preprocess the image
# ---> 35 img = preprocess_image(image_path)
#      37 # Reconstruct the image with the autoencoder
#      38 reconstructed_img = autoencoder.predict(img)
#
# Cell In[14], line 9, in preprocess_image(image_path, target_size)
#       7 """Load and preprocess an image for the autoencoder."""
#       8 img = cv2.imread(image_path)
# ----> 9 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#      10 img = cv2.resize(img, target_size)
#      11 img = img.astype('float32') / 255.0  # Normalize to [0, 1] and set to float32
#
# error: OpenCV(4.10.0) /io/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
