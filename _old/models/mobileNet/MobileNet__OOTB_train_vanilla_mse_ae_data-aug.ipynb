# %%
# !pip3 install -r ../../requirements.txt
# Out:
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.12/site-packages (from -r ../../requirements.txt (line 1)) (6.29.5)
# Requirement already satisfied: matplotlib==3.9.2 in /opt/conda/lib/python3.12/site-packages (from -r ../../requirements.txt (line 2)) (3.9.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.12/site-packages (from -r ../../requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: opencv-python==4.10.0.84 in /opt/conda/lib/python3.12/site-packages (from -r ../../requirements.txt (line 4)) (4.10.0.84)
# Requirement already satisfied: pandas==2.2.3 in /opt/conda/lib/python3.12/site-packages (from -r ../../requirements.txt (line 5)) (2.2.3)
# Requirement already satisfied: scikit-learn==1.5.2 in /opt/conda/lib/python3.12/site-packages (from -r ../../requirements.txt (line 6)) (1.5.2)
# Requirement already satisfied: seaborn==0.13.2 in /opt/conda/lib/python3.12/site-packages (from -r ../../requirements.txt (line 7)) (0.13.2)
# Requirement already satisfied: tensorflow==2.18.0 in /opt/conda/lib/python3.12/site-packages (from -r ../../requirements.txt (line 8)) (2.18.0)
# Requirement already satisfied: tqdm==4.67.0 in /opt/conda/lib/python3.12/site-packages (from -r ../../requirements.txt (line 9)) (4.67.0)
# Requirement already satisfied: wandb==0.18.6 in /opt/conda/lib/python3.12/site-packages (from -r ../../requirements.txt (line 10)) (0.18.6)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../../requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../../requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../../requirements.txt (line 2)) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../../requirements.txt (line 2)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../../requirements.txt (line 2)) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../../requirements.txt (line 2)) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../../requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../../requirements.txt (line 2)) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.3->-r ../../requirements.txt (line 5)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.3->-r ../../requirements.txt (line 5)) (2024.2)
# Requirement already satisfied: scipy>=1.6.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn==1.5.2->-r ../../requirements.txt (line 6)) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn==1.5.2->-r ../../requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn==1.5.2->-r ../../requirements.txt (line 6)) (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (5.29.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (75.3.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (1.68.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (3.7.0)
# Requirement already satisfied: h5py>=3.11.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (0.4.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.12/site-packages (from wandb==0.18.6->-r ../../requirements.txt (line 10)) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from wandb==0.18.6->-r ../../requirements.txt (line 10)) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from wandb==0.18.6->-r ../../requirements.txt (line 10)) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.12/site-packages (from wandb==0.18.6->-r ../../requirements.txt (line 10)) (4.3.6)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.12/site-packages (from wandb==0.18.6->-r ../../requirements.txt (line 10)) (6.1.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.12/site-packages (from wandb==0.18.6->-r ../../requirements.txt (line 10)) (6.0.2)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from wandb==0.18.6->-r ../../requirements.txt (line 10)) (2.19.2)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.12/site-packages (from wandb==0.18.6->-r ../../requirements.txt (line 10)) (1.3.4)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->-r ../../requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.12/site-packages (from ipykernel->-r ../../requirements.txt (line 1)) (1.8.8)
# Requirement already satisfied: ipython>=7.23.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->-r ../../requirements.txt (line 1)) (8.29.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.12/site-packages (from ipykernel->-r ../../requirements.txt (line 1)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.12/site-packages (from ipykernel->-r ../../requirements.txt (line 1)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->-r ../../requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.12/site-packages (from ipykernel->-r ../../requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.12/site-packages (from ipykernel->-r ../../requirements.txt (line 1)) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.12/site-packages (from ipykernel->-r ../../requirements.txt (line 1)) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/conda/lib/python3.12/site-packages (from ipykernel->-r ../../requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (0.45.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.12/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb==0.18.6->-r ../../requirements.txt (line 10)) (4.0.11)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (2.18.0)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: rich in /opt/conda/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (13.9.4)
# Requirement already satisfied: namex in /opt/conda/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (0.0.8)
# Requirement already satisfied: optree in /opt/conda/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (3.1.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb==0.18.6->-r ../../requirements.txt (line 10)) (5.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/conda/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r ../../requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow==2.18.0->-r ../../requirements.txt (line 8)) (0.1.2)

# %%
import os
import sys

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose, LeakyReLU, BatchNormalization, Flatten, Dense, Reshape, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import wandb
from wandb.integration.keras import WandbMetricsLogger, WandbModelCheckpoint

# modify sys.path for it to contain the main repo path so we can import modules such as below
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '../..'))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

from utils.helper import get_root_dir, set_seed, setup_gpu
from utils.data import load_data_with_test_split
from utils.plots import plot_reconstructions, plot_history
from utils.latent_space import plot_latent_space
from utils.evaluation import evaluate_autoencoder, ssim_loss, ssim_l1_loss, dssim_loss, evaluate_autoencoder_with_threshold_generator

# %%
# Hyperparameter to tune
config = {
    "comment" : "test wandb",
    "epochs" : 100,
    "loss" : 'mse',
    "optimizer" : "adam",
    "dropout": True,
    "dropout_value" : 0.0,
    "rotation_range" : 90,
    "batch_size" : 16,
    "latent_dim" : 512,
    "threshold_percentage" : 80,
    "data_class" : "screw",
    "model_type" : "autoencoder"
}

# Rather static parameters, no need to track
IMAGE_SIZE = (256, 256)
INPUT_SHAPE = IMAGE_SIZE + (3,)

# %%
wandb.init(project="MobileNet", config=config)
config = wandb.config # this turns our hyperparameter config into a proper object with attributes
wandb.define_metric('val_loss', summary='min')
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: wilmer-nystrom (itu-aml-project). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>/work/itu-aml-anomaly-detection/models/autoencoder/wandb/run-20241227_133745-s0afeofj</code>
# Syncing run <strong><a href='https://wandb.ai/itu-aml-project/MobileNet/runs/s0afeofj' target="_blank">major-surf-6</a></strong> to <a href='https://wandb.ai/itu-aml-project/MobileNet' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/itu-aml-project/MobileNet' target="_blank">https://wandb.ai/itu-aml-project/MobileNet</a>
#  View run at <a href='https://wandb.ai/itu-aml-project/MobileNet/runs/s0afeofj' target="_blank">https://wandb.ai/itu-aml-project/MobileNet/runs/s0afeofj</a>

# %%
root_dir = get_root_dir()
# root_dir = 'Mini Project'

set_seed(1234)

model_dir = os.path.join(root_dir, 'models', config.model_type)

cpkt_path = os.path.join(model_dir, 'logs', 'checkpoints', f'{config.comment}_checkpoint.model.keras')
weights_path = os.path.join(model_dir, 'logs', 'weights', f'{config.comment}_model.keras')
assert not os.path.exists(weights_path), f'Path already exists: {weights_path}. Please change the comment.'

# %%
train_generator, validation_generator, test_generator, threshold_generator = load_data_with_test_split(
    category="screw",
    batch_size=32,
    test_split=0.4,
    rotation_range=config.rotation_range
)
# Out:
# Found 256 images belonging to 1 classes.
# Found 64 images belonging to 1 classes.
# Found 98 images belonging to 6 classes.
# Found 62 images belonging to 6 classes.

# %%
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Dense, Flatten, Reshape, UpSampling2D, Conv2D, BatchNormalization, LeakyReLU
from tensorflow.keras.applications import MobileNet

def mobile_autoencoder(input_shape=(256, 256, 3), optimizer='', latent_dim=512, loss='mse'):
    """
    input_shape (tuple): Shape of the input images (height, width, channels).
    latent_dim (int): Dimension of the latent space.
    loss (str): Loss used to train the autoencoder. Options: 'mse', 'ssim', etc.
    """
    # Encoder - MobileNet as the encoder
    input_img = Input(shape=input_shape)

    # Load MobileNet without the top classification layers (include_top=False)
    mobilenet_base = MobileNet(input_shape=input_shape, include_top=False, weights='imagenet')

    # Freeze the MobileNet layers for feature extraction
    mobilenet_base.trainable = False

    # Use the output of the last convolutional layer of MobileNet
    x = mobilenet_base(input_img)
    x = Flatten()(x)  # Flatten the output of MobileNet
    encoded = Dense(latent_dim)(x)  # Latent space size reduced to 'latent_dim'
    encoded = BatchNormalization()(encoded)
    encoded = LeakyReLU(name='bottleneck')(encoded)

    # Decoder - Upsampling to match the original input size (256x256)
    x = Dense(8 * 8 * 1024)(encoded)  # Adjust to match dimensions that can upscale properly
    x = Reshape((8, 8, 1024))(x)  # Reshape into 8x8x1024

    x = UpSampling2D((2, 2))(x)  # (16, 16, 1024)
    x = Conv2D(512, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = UpSampling2D((2, 2))(x)  # (32, 32, 512)
    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = UpSampling2D((2, 2))(x)  # (64, 64, 256)
    x = Conv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = UpSampling2D((2, 2))(x)  # (128, 128, 128)
    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = UpSampling2D((2, 2))(x)  # (256, 256, 64)
    x = Conv2D(input_shape[2], (3, 3), activation='sigmoid', padding='same')(x)

    # Autoencoder Model
    autoencoder = Model(input_img, x)
    autoencoder.compile(optimizer=optimizer, loss=loss)
    return autoencoder

# Get correct loss from config
if config.loss == 'mae': 
    loss = 'mae'
elif config.loss == 'mse': 
    loss = 'mse'
elif config.loss == 'dssim_loss': 
    loss = dssim_loss
elif config.loss == 'ssim_loss': 
    loss = ssim_loss
elif config.loss == 'ssim_l1_loss': 
    loss = ssim_l1_loss
else:
    raise ValueError(f"Unknown loss function: {config.loss}. Please define a function to calculate the error.")

print(f"Used Loss to train: {loss}")
print(f"Optimizer: {config.optimizer}")

# Initialize and compile the autoencoder
autoencoder = mobile_autoencoder(
    input_shape=INPUT_SHAPE, 
    optimizer=config.optimizer, 
    latent_dim=config.latent_dim, 
    loss=loss
)

print("Input shape:", autoencoder.input_shape)
print("Output shape:", autoencoder.output_shape)

autoencoder.summary()
# Out:
# Used Loss to train: mse
# Optimizer: adam
# /tmp/ipykernel_17682/816717967.py:15: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   mobilenet_base = MobileNet(input_shape=input_shape, include_top=False, weights='imagenet')
# Input shape: (None, 256, 256, 3)
# Output shape: (None, 256, 256, 3)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenet_1.00_224 (Functional) │ (None, 8, 8, 1024)     │     3,228,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 65536)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    33,554,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bottleneck (LeakyReLU)          │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 65536)          │    33,619,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 8, 8, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 16, 16, 1024)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 16, 16, 512)    │     4,719,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 16, 16, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 16, 16, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 32, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 256)    │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 32, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_2 (UpSampling2D)  │ (None, 64, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 64, 64, 128)    │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 64, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_3 (UpSampling2D)  │ (None, 128, 128, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 128, 128, 64)   │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 128, 128, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_4 (UpSampling2D)  │ (None, 256, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 256, 256, 3)    │         1,731 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 76,679,235 (292.51 MB)
#  Trainable params: 73,447,427 (280.18 MB)
#  Non-trainable params: 3,231,808 (12.33 MB)

# %%
#define early stopping and checkpoints
early_stop = EarlyStopping(
    monitor="val_loss", 
    mode="min",
    patience=20, 
    start_from_epoch=250
    )

history = autoencoder.fit(
    train_generator,
    epochs=config.epochs,
    #epochs = 200,
    validation_data=validation_generator,
    callbacks=[
        early_stop,
       WandbMetricsLogger(),
       WandbModelCheckpoint(f"models/checkpoints/{config.comment}.keras", verbose=1, save_best_only=True), # Saves model checkpoint to W&B
    ],
)
# Out:
# wandb: WARNING When using `save_best_only`, ensure that the `filepath` argument contains formatting placeholders like `{epoch:02d}` or `{batch:02d}`. This ensures correct interpretation of the logged artifacts.
# /opt/conda/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 735ms/step - loss: 0.0550
# Epoch 1: val_loss improved from inf to 0.10517, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - loss: 0.0526 - val_loss: 0.1052
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 744ms/step - loss: 0.0085
# Epoch 2: val_loss did not improve from 0.10517
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0085 - val_loss: 0.1275
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - loss: 0.0073
# Epoch 3: val_loss did not improve from 0.10517
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0072 - val_loss: 0.1297
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 749ms/step - loss: 0.0063
# Epoch 4: val_loss did not improve from 0.10517
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0063 - val_loss: 0.1331
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 737ms/step - loss: 0.0062
# Epoch 5: val_loss did not improve from 0.10517
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0062 - val_loss: 0.1186
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 737ms/step - loss: 0.0060
# Epoch 6: val_loss improved from 0.10517 to 0.09470, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0060 - val_loss: 0.0947
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 740ms/step - loss: 0.0057
# Epoch 7: val_loss improved from 0.09470 to 0.08059, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0057 - val_loss: 0.0806
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 758ms/step - loss: 0.0054
# Epoch 8: val_loss improved from 0.08059 to 0.06549, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0054 - val_loss: 0.0655
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 735ms/step - loss: 0.0054
# Epoch 9: val_loss improved from 0.06549 to 0.04973, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0053 - val_loss: 0.0497
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 744ms/step - loss: 0.0050
# Epoch 10: val_loss improved from 0.04973 to 0.03232, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0050 - val_loss: 0.0323
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 737ms/step - loss: 0.0050
# Epoch 11: val_loss improved from 0.03232 to 0.02278, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0050 - val_loss: 0.0228
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 775ms/step - loss: 0.0049
# Epoch 12: val_loss improved from 0.02278 to 0.01838, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0049 - val_loss: 0.0184
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 740ms/step - loss: 0.0044
# Epoch 13: val_loss improved from 0.01838 to 0.01369, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0044 - val_loss: 0.0137
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 746ms/step - loss: 0.0046
# Epoch 14: val_loss improved from 0.01369 to 0.00805, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0045 - val_loss: 0.0081
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 744ms/step - loss: 0.0041
# Epoch 15: val_loss did not improve from 0.00805
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0041 - val_loss: 0.0091
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 742ms/step - loss: 0.0037
# Epoch 16: val_loss improved from 0.00805 to 0.00688, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0037 - val_loss: 0.0069
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 748ms/step - loss: 0.0035
# Epoch 17: val_loss improved from 0.00688 to 0.00687, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0035 - val_loss: 0.0069
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 759ms/step - loss: 0.0036
# Epoch 18: val_loss improved from 0.00687 to 0.00546, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0036 - val_loss: 0.0055
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 757ms/step - loss: 0.0037
# Epoch 19: val_loss improved from 0.00546 to 0.00520, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0037 - val_loss: 0.0052
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 742ms/step - loss: 0.0033
# Epoch 20: val_loss improved from 0.00520 to 0.00493, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0033 - val_loss: 0.0049
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - loss: 0.0032
# Epoch 21: val_loss improved from 0.00493 to 0.00389, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0032 - val_loss: 0.0039
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 749ms/step - loss: 0.0031
# Epoch 22: val_loss improved from 0.00389 to 0.00342, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 744ms/step - loss: 0.0032
# Epoch 23: val_loss improved from 0.00342 to 0.00335, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 749ms/step - loss: 0.0033
# Epoch 24: val_loss did not improve from 0.00335
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - loss: 0.0030
# Epoch 25: val_loss did not improve from 0.00335
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 744ms/step - loss: 0.0028
# Epoch 26: val_loss improved from 0.00335 to 0.00334, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0028 - val_loss: 0.0033
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 739ms/step - loss: 0.0031
# Epoch 27: val_loss did not improve from 0.00334
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0031 - val_loss: 0.0037
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 750ms/step - loss: 0.0028
# Epoch 28: val_loss improved from 0.00334 to 0.00292, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 742ms/step - loss: 0.0029
# Epoch 29: val_loss did not improve from 0.00292
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 736ms/step - loss: 0.0029
# Epoch 30: val_loss improved from 0.00292 to 0.00275, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0029 - val_loss: 0.0027
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 740ms/step - loss: 0.0028
# Epoch 31: val_loss did not improve from 0.00275
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 759ms/step - loss: 0.0028
# Epoch 32: val_loss did not improve from 0.00275
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 760ms/step - loss: 0.0028
# Epoch 33: val_loss improved from 0.00275 to 0.00259, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 746ms/step - loss: 0.0027
# Epoch 34: val_loss improved from 0.00259 to 0.00236, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - loss: 0.0025
# Epoch 35: val_loss improved from 0.00236 to 0.00233, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 742ms/step - loss: 0.0023
# Epoch 36: val_loss improved from 0.00233 to 0.00224, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - loss: 0.0024
# Epoch 37: val_loss improved from 0.00224 to 0.00218, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 742ms/step - loss: 0.0026
# Epoch 38: val_loss did not improve from 0.00218
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 739ms/step - loss: 0.0029
# Epoch 39: val_loss did not improve from 0.00218
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 756ms/step - loss: 0.0025
# Epoch 40: val_loss improved from 0.00218 to 0.00217, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - loss: 0.0023
# Epoch 41: val_loss did not improve from 0.00217
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - loss: 0.0024
# Epoch 42: val_loss improved from 0.00217 to 0.00217, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - loss: 0.0025
# Epoch 43: val_loss improved from 0.00217 to 0.00216, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 763ms/step - loss: 0.0026
# Epoch 44: val_loss did not improve from 0.00216
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 737ms/step - loss: 0.0026
# Epoch 45: val_loss did not improve from 0.00216
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - loss: 0.0025
# Epoch 46: val_loss did not improve from 0.00216
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 742ms/step - loss: 0.0024
# Epoch 47: val_loss did not improve from 0.00216
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 767ms/step - loss: 0.0025
# Epoch 48: val_loss improved from 0.00216 to 0.00215, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 745ms/step - loss: 0.0023
# Epoch 49: val_loss improved from 0.00215 to 0.00214, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 751ms/step - loss: 0.0023
# Epoch 50: val_loss did not improve from 0.00214
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - loss: 0.0024
# Epoch 51: val_loss improved from 0.00214 to 0.00206, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 758ms/step - loss: 0.0024
# Epoch 52: val_loss improved from 0.00206 to 0.00205, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 745ms/step - loss: 0.0023
# Epoch 53: val_loss did not improve from 0.00205
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 760ms/step - loss: 0.0025
# Epoch 54: val_loss did not improve from 0.00205
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 744ms/step - loss: 0.0025
# Epoch 55: val_loss did not improve from 0.00205
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 737ms/step - loss: 0.0025
# Epoch 56: val_loss improved from 0.00205 to 0.00204, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 752ms/step - loss: 0.0023
# Epoch 57: val_loss improved from 0.00204 to 0.00196, saving model to models/checkpoints/test wandb.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 752ms/step - loss: 0.0022
# Epoch 58: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 724ms/step - loss: 0.0023
# Epoch 59: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 749ms/step - loss: 0.0025
# Epoch 60: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - loss: 0.0023
# Epoch 61: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 735ms/step - loss: 0.0023
# Epoch 62: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 752ms/step - loss: 0.0022
# Epoch 63: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 737ms/step - loss: 0.0023
# Epoch 64: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 739ms/step - loss: 0.0023
# Epoch 65: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - loss: 0.0022
# Epoch 66: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 738ms/step - loss: 0.0023
# Epoch 67: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 752ms/step - loss: 0.0022
# Epoch 68: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 742ms/step - loss: 0.0021
# Epoch 69: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 746ms/step - loss: 0.0020
# Epoch 70: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 741ms/step - loss: 0.0021
# Epoch 71: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - loss: 0.0022
# Epoch 72: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 738ms/step - loss: 0.0022
# Epoch 73: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - loss: 0.0022
# Epoch 74: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - loss: 0.0021
# Epoch 75: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 738ms/step - loss: 0.0022
# Epoch 76: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 738ms/step - loss: 0.0020
# Epoch 77: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 749ms/step - loss: 0.0020
# Epoch 78: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 740ms/step - loss: 0.0020
# Epoch 79: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 745ms/step - loss: 0.0021
# Epoch 80: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 739ms/step - loss: 0.0020
# Epoch 81: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 738ms/step - loss: 0.0020
# Epoch 82: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - loss: 0.0020
# Epoch 83: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - loss: 0.0020
# Epoch 84: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - loss: 0.0020
# Epoch 85: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - loss: 0.0019
# Epoch 86: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 748ms/step - loss: 0.0020
# Epoch 87: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 740ms/step - loss: 0.0019
# Epoch 88: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 738ms/step - loss: 0.0021
# Epoch 89: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 741ms/step - loss: 0.0019
# Epoch 90: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 736ms/step - loss: 0.0020
# Epoch 91: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - loss: 0.0020
# Epoch 92: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - loss: 0.0020
# Epoch 93: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 744ms/step - loss: 0.0019
# Epoch 94: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - loss: 0.0019
# Epoch 95: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 744ms/step - loss: 0.0019
# Epoch 96: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 746ms/step - loss: 0.0018
# Epoch 97: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 745ms/step - loss: 0.0021
# Epoch 98: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - loss: 0.0019
# Epoch 99: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - loss: 0.0019
# Epoch 100: val_loss did not improve from 0.00196
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - loss: 0.0019 - val_loss: 0.0022

# %%
# plot the training history
plot_history(comment=config.comment, history=history, wandb=wandb)
# Out:
# Best train_loss: 0.0018
# Best val_loss: 0.002
# Last improvement of val_loss at epoch: 57

# %%
plot_reconstructions(autoencoder, test_generator, n_images=5, title='Test', wandb=wandb)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step

# %%
import importlib
import utils.evaluation

# Reload the module to ensure the latest changes are loaded
importlib.reload(utils.evaluation)

from utils.evaluation import evaluate_autoencoder

# Evaluate the autoencoder using the provided test and validation generators
evaluate_autoencoder(
    autoencoder=autoencoder,
    validation_generator=validation_generator,  # Assuming this is defined elsewhere
    test_generator=test_generator,
    config=config,
    wandb=wandb
)
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.00      0.00      0.00        26
#      Anomaly       0.33      0.18      0.23        72
#
#     accuracy                           0.13        98
#    macro avg       0.17      0.09      0.12        98
# weighted avg       0.24      0.13      0.17        98

# %%
plot_latent_space(autoencoder, test_generator, wandb, layer_name='bottleneck')

# %%
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np

def preprocess_image(image_path, target_size=(256, 256)):
    """Load and preprocess an image for the autoencoder."""
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, target_size)
    img = img.astype('float32') / 255.0  # Normalize to [0, 1] and set to float32
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    return img

def calculate_reconstruction_error(original, reconstructed):
    """Calculate the mean squared error between original and reconstructed images."""
    return np.mean((original - reconstructed) ** 2)

def predict_anomaly_and_plot(autoencoder, image_path, mask_dir, threshold=0.02):
    """
    Predict if an image is an anomaly based on reconstruction error
    and plot original, reconstructed, and mask images.
    
    Parameters:
        autoencoder (Model): The trained autoencoder model.
        image_path (str): Path to the image file.
        mask_dir (str): Directory containing anomaly mask images.
        threshold (float): Error threshold to classify as anomaly.
    
    Returns:
        bool: True if anomaly, False otherwise.
        float: The reconstruction error.
    """
    # Preprocess the image
    img = preprocess_image(image_path)
    
    # Reconstruct the image with the autoencoder
    reconstructed_img = autoencoder.predict(img)

    # Ensure reconstructed image is in float32 format
    reconstructed_img = reconstructed_img.astype('float32')
    
    # Calculate reconstruction error
    error = calculate_reconstruction_error(img, reconstructed_img)
    
    # Classify as anomaly if error exceeds the threshold
    is_anomaly = error > threshold

    # Generate the corresponding mask path
    file_name = os.path.basename(image_path).split('.')[0] + '_mask.png'
    label = os.path.basename(os.path.dirname(image_path))
    mask_path = os.path.join(mask_dir, label, file_name)
    
    # Load the mask image if it exists
    if os.path.exists(mask_path):
        mask_img = plt.imread(mask_path)
    else:
        mask_img = None

    # Plot original, reconstructed, and mask images
    plt.figure(figsize=(12, 4))
    
    # Original image
    plt.subplot(1, 3, 1)
    plt.imshow(img[0])  # Remove batch dimension for display
    plt.title("Original Image")
    plt.axis("off")
    
    # Reconstructed image
    plt.subplot(1, 3, 2)
    plt.imshow(reconstructed_img[0])  # Remove batch dimension for display
    plt.title("Reconstructed Image")
    plt.axis("off")
    
    # Anomaly mask
    plt.subplot(1, 3, 3)
    if mask_img is not None:
        plt.imshow(mask_img, cmap="gray")
        plt.title("Anomaly Mask")
    else:
        plt.text(0.5, 0.5, 'No Mask Available', ha='center', va='center', fontsize=12)
    plt.axis("off")
    
    plt.suptitle(f"Reconstruction Error: {error:.4f}| Threshold: {threshold} | Anomaly: {'Yes' if is_anomaly else 'No'}")
    plt.show()
    
    return is_anomaly, error

# Example usage
# Example usage
"""mask_dir = '../../data/screw/ground_truth'
image_paths = [
    '../../data/screw/test/manipulated_front/001.png',
    '../../data/screw/test/scratch_head/001.png', 
    '../../data/screw/test/scratch_neck/001.png' 
]"""
mask_dir = 'data/screw/ground_truth'
image_paths = [
    'data/screw/test/manipulated_front/001.png',
    'data/screw/test/scratch_head/001.png', 
    'data/screw/test/scratch_neck/001.png' 
]
for path in image_paths: 
    is_anomaly, error = predict_anomaly_and_plot(autoencoder, path, mask_dir)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[13], line 104
#      98 image_paths = [
#      99     'data/screw/test/manipulated_front/001.png',
#     100     'data/screw/test/scratch_head/001.png',
#     101     'data/screw/test/scratch_neck/001.png'
#     102 ]
#     103 for path in image_paths:
# --> 104     is_anomaly, error = predict_anomaly_and_plot(autoencoder, path, mask_dir)
#
# Cell In[13], line 35, in predict_anomaly_and_plot(autoencoder, image_path, mask_dir, threshold)
#      20 """
#      21 Predict if an image is an anomaly based on reconstruction error
#      22 and plot original, reconstructed, and mask images.
#    (...)
#      32     float: The reconstruction error.
#      33 """
#      34 # Preprocess the image
# ---> 35 img = preprocess_image(image_path)
#      37 # Reconstruct the image with the autoencoder
#      38 reconstructed_img = autoencoder.predict(img)
#
# Cell In[13], line 9, in preprocess_image(image_path, target_size)
#       7 """Load and preprocess an image for the autoencoder."""
#       8 img = cv2.imread(image_path)
# ----> 9 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#      10 img = cv2.resize(img, target_size)
#      11 img = img.astype('float32') / 255.0  # Normalize to [0, 1] and set to float32
#
# error: OpenCV(4.10.0) /io/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
wandb.finish()
