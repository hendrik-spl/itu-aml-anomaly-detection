# %%
import os
import sys

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose, LeakyReLU, BatchNormalization, Flatten, Dense, Reshape, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import wandb
from wandb.integration.keras import WandbMetricsLogger, WandbModelCheckpoint

# modify sys.path for it to contain the main repo path so we can import modules such as below
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '../..'))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

from utils.helper import get_root_dir, set_seed, setup_gpu
from utils.data import load_data_with_test_split
from utils.plots import plot_reconstructions, plot_history
from utils.latent_space import plot_latent_space
from utils.evaluation import evaluate_autoencoder, ssim_loss, ssim_l1_loss, dssim_loss, evaluate_autoencoder_with_distribution_threshold, evaluate_autoencoder_with_threshold_generator

# %%
# Hyperparameter to tune
config = {
    "comment" : "Vanilla AE - SSIM",
    "epochs" : 100,
    "loss" : 'ssim',
    "optimizer" : "adam",
    "dropout": True,
    "dropout_value" : 0.3,
    "batch_size" : 16,
    "latent_dim" : 512,
    "threshold_percentage" : 80,
    "data_class" : "screw",
    "model_type" : "autoencoder"
}

# Rather static parameters, no need to track
IMAGE_SIZE = (256, 256)
INPUT_SHAPE = IMAGE_SIZE + (3,)

# %%
wandb.init(project="itu-aml-project", config=config)
config = wandb.config # this turns our hyperparameter config into a proper object with attributes
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········
# wandb: Appending key for api.wandb.ai to your netrc file: /home/ucloud/.netrc
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>/work/Mini Project/models/autoencoder/wandb/run-20241203_120451-2ph5jyzg</code>
# Syncing run <strong><a href='https://wandb.ai/itu-aml-project/itu-aml-project/runs/2ph5jyzg' target="_blank">fresh-morning-49</a></strong> to <a href='https://wandb.ai/itu-aml-project/itu-aml-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/itu-aml-project/itu-aml-project' target="_blank">https://wandb.ai/itu-aml-project/itu-aml-project</a>
#  View run at <a href='https://wandb.ai/itu-aml-project/itu-aml-project/runs/2ph5jyzg' target="_blank">https://wandb.ai/itu-aml-project/itu-aml-project/runs/2ph5jyzg</a>

# %%
#root_dir = get_root_dir()
root_dir = 'Mini Project'

set_seed(1234)

model_dir = os.path.join(root_dir, 'models', config.model_type)

cpkt_path = os.path.join(model_dir, 'logs', 'checkpoints', f'{config.comment}_checkpoint.model.keras')
weights_path = os.path.join(model_dir, 'logs', 'weights', f'{config.comment}_model.keras')
assert not os.path.exists(weights_path), f'Path already exists: {weights_path}. Please change the comment.'

# %%
train_generator, validation_generator, test_generator, threshold_generator = load_data_with_test_split(
    category="screw",
    batch_size=32,
    test_split=0.4
)
# Out:
# Found 256 images belonging to 1 classes.
# Found 64 images belonging to 1 classes.
# Found 98 images belonging to 6 classes.
# Found 62 images belonging to 6 classes.

# %%
def vanilla_autoencoder(input_shape=INPUT_SHAPE, optimizer='', latent_dim=512, loss='mse'):
    """
        input_shape (tuple): Shape of the input images (height, width, channels).
        latent_dim (int): Dimension of the latent space.
        loss (str): Loss used to train the autoencoder. Options: 'mse', 'ssim', etc.
    """
    # Encoder
    input_img = Input(shape=input_shape)

    # Encoder with reduced complexity
    x = Conv2D(32, (3, 3), padding='same')(input_img)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = MaxPooling2D((2, 2), padding='same')(x)  # (128, 128, 32)
    x = Dropout(0.3)(x)

    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = MaxPooling2D((2, 2), padding='same')(x)  # (64, 64, 64)
    x = Dropout(0.3)(x)

    x = Conv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = MaxPooling2D((2, 2), padding='same')(x)  # (32, 32, 128)
    x = Dropout(0.3)(x)

    # Bottleneck
    x = Flatten()(x)  # Flattened Shape: (32 * 32 * 128,)
    encoded = Dense(latent_dim)(x)  # Latent space size reduced to 526
    encoded = BatchNormalization()(encoded)
    encoded = LeakyReLU(name='bottleneck')(encoded)

    # Decoder with reduced complexity
    x = Dense(32 * 32 * 128)(encoded)
    x = Reshape((32, 32, 128))(x)

    x = UpSampling2D((2, 2))(x)  # (64, 64, 128)
    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = UpSampling2D((2, 2))(x)  # (128, 128, 64)
    x = Conv2D(32, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = UpSampling2D((2, 2))(x)  # (256, 256, 32)
    x = Conv2D(input_shape[2], (3, 3), activation='sigmoid', padding='same')(x)

    # Autoencoder Model
    autoencoder = Model(input_img, x)
    autoencoder.compile(optimizer=optimizer, loss=loss)
    return autoencoder

# get correct loss from config as functions are not callable from config itself
if config.loss == 'mae': loss = 'mae'
elif config.loss == 'mse': loss = 'mse'
elif config.loss == 'dssim': loss = dssim_loss
elif config.loss == 'ssim': loss = ssim_loss
elif config.loss == 'ssim_l1': loss = ssim_l1_loss
else:
    raise ValueError(f"Unknown loss function: {config.loss}. Please define a function to calculate the error.")

print(f"Used Loss to train:{loss}")
print(f"Optimizer: {config.optimizer}")

autoencoder = vanilla_autoencoder(
    input_shape=INPUT_SHAPE, 
    optimizer=config.optimizer, 
    latent_dim=config.latent_dim, 
    loss=loss
)


print("Input shape:", autoencoder.input_shape)
print("Output shape:", autoencoder.output_shape)

autoencoder.summary()
# Out:
# Used Loss to train:<function ssim_loss at 0x7ff435c15120>
# Optimizer: adam
# Input shape: (None, 256, 256, 3)
# Output shape: (None, 256, 256, 3)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256, 256, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 256, 256, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 128, 128, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128, 128, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 131072)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    67,109,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bottleneck (LeakyReLU)          │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 131072)         │    67,239,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 64, 64, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 128, 128, 32)   │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_2 (UpSampling2D)  │ (None, 256, 256, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 256, 256, 3)    │           867 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 134,539,011 (513.23 MB)
#  Trainable params: 134,537,347 (513.22 MB)
#  Non-trainable params: 1,664 (6.50 KB)

# %%
#define early stopping and checkpoints
early_stop = EarlyStopping(
    monitor="val_loss", 
    mode="min",
    patience=20, 
    start_from_epoch=20
    )

checkpoint = ModelCheckpoint(
    cpkt_path, 
    monitor="val_loss", 
    mode="min", 
    save_best_only=True, 
    verbose=1
    )

history = autoencoder.fit(
    train_generator,
    epochs=config.epochs,
    validation_data=validation_generator,
    callbacks=[
        early_stop,
        checkpoint,
        WandbMetricsLogger(),
        # WandbModelCheckpoint("models"), # Saves model checkpoint to W&B
    ],
)

wandb.finish()
# Out:
# /opt/conda/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.7420
# Epoch 1: val_loss improved from inf to 0.34210, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 0.7219 - val_loss: 0.3421
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - loss: 0.3103
# Epoch 2: val_loss improved from 0.34210 to 0.26293, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 978ms/step - loss: 0.3080 - val_loss: 0.2629
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - loss: 0.2519
# Epoch 3: val_loss improved from 0.26293 to 0.23804, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 976ms/step - loss: 0.2510 - val_loss: 0.2380
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - loss: 0.2251
# Epoch 4: val_loss improved from 0.23804 to 0.22287, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 997ms/step - loss: 0.2246 - val_loss: 0.2229
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - loss: 0.2057
# Epoch 5: val_loss improved from 0.22287 to 0.21251, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 979ms/step - loss: 0.2055 - val_loss: 0.2125
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - loss: 0.1933
# Epoch 6: val_loss improved from 0.21251 to 0.20984, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 983ms/step - loss: 0.1930 - val_loss: 0.2098
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - loss: 0.1826
# Epoch 7: val_loss improved from 0.20984 to 0.20789, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 987ms/step - loss: 0.1823 - val_loss: 0.2079
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - loss: 0.1728
# Epoch 8: val_loss improved from 0.20789 to 0.20396, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 992ms/step - loss: 0.1727 - val_loss: 0.2040
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - loss: 0.1658
# Epoch 9: val_loss improved from 0.20396 to 0.20183, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 992ms/step - loss: 0.1658 - val_loss: 0.2018
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 526ms/step - loss: 0.1601
# Epoch 10: val_loss improved from 0.20183 to 0.19962, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 985ms/step - loss: 0.1602 - val_loss: 0.1996
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - loss: 0.1561
# Epoch 11: val_loss improved from 0.19962 to 0.19893, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 982ms/step - loss: 0.1561 - val_loss: 0.1989
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - loss: 0.1518
# Epoch 12: val_loss improved from 0.19893 to 0.19806, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 986ms/step - loss: 0.1519 - val_loss: 0.1981
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - loss: 0.1491
# Epoch 13: val_loss improved from 0.19806 to 0.19745, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 999ms/step - loss: 0.1490 - val_loss: 0.1974
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - loss: 0.1467
# Epoch 14: val_loss improved from 0.19745 to 0.19740, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 985ms/step - loss: 0.1468 - val_loss: 0.1974
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - loss: 0.1445
# Epoch 15: val_loss improved from 0.19740 to 0.19720, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 972ms/step - loss: 0.1445 - val_loss: 0.1972
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - loss: 0.1433
# Epoch 16: val_loss did not improve from 0.19720
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 642ms/step - loss: 0.1432 - val_loss: 0.1976
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - loss: 0.1405
# Epoch 17: val_loss did not improve from 0.19720
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 649ms/step - loss: 0.1404 - val_loss: 0.1973
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - loss: 0.1395
# Epoch 18: val_loss improved from 0.19720 to 0.19716, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 991ms/step - loss: 0.1395 - val_loss: 0.1972
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - loss: 0.1364
# Epoch 19: val_loss improved from 0.19716 to 0.19698, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 970ms/step - loss: 0.1367 - val_loss: 0.1970
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - loss: 0.1368
# Epoch 20: val_loss did not improve from 0.19698
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 639ms/step - loss: 0.1368 - val_loss: 0.1974
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - loss: 0.1352
# Epoch 21: val_loss did not improve from 0.19698
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 643ms/step - loss: 0.1353 - val_loss: 0.1973
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - loss: 0.1335
# Epoch 22: val_loss did not improve from 0.19698
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 649ms/step - loss: 0.1336 - val_loss: 0.1970
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - loss: 0.1321
# Epoch 23: val_loss did not improve from 0.19698
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 645ms/step - loss: 0.1323 - val_loss: 0.1971
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - loss: 0.1314
# Epoch 24: val_loss improved from 0.19698 to 0.19657, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 975ms/step - loss: 0.1314 - val_loss: 0.1966
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - loss: 0.1290
# Epoch 25: val_loss did not improve from 0.19657
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 650ms/step - loss: 0.1290 - val_loss: 0.1967
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - loss: 0.1297
# Epoch 26: val_loss improved from 0.19657 to 0.19642, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 977ms/step - loss: 0.1296 - val_loss: 0.1964
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - loss: 0.1283
# Epoch 27: val_loss improved from 0.19642 to 0.19640, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 984ms/step - loss: 0.1283 - val_loss: 0.1964
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - loss: 0.1265
# Epoch 28: val_loss improved from 0.19640 to 0.19623, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 979ms/step - loss: 0.1265 - val_loss: 0.1962
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - loss: 0.1258
# Epoch 29: val_loss improved from 0.19623 to 0.19605, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 987ms/step - loss: 0.1258 - val_loss: 0.1960
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - loss: 0.1226
# Epoch 30: val_loss did not improve from 0.19605
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 640ms/step - loss: 0.1227 - val_loss: 0.1961
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - loss: 0.1225
# Epoch 31: val_loss did not improve from 0.19605
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 644ms/step - loss: 0.1226 - val_loss: 0.1962
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 527ms/step - loss: 0.1217
# Epoch 32: val_loss did not improve from 0.19605
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 651ms/step - loss: 0.1217 - val_loss: 0.1961
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - loss: 0.1207
# Epoch 33: val_loss improved from 0.19605 to 0.19560, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 986ms/step - loss: 0.1207 - val_loss: 0.1956
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - loss: 0.1188
# Epoch 34: val_loss did not improve from 0.19560
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 657ms/step - loss: 0.1188 - val_loss: 0.1957
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - loss: 0.1175
# Epoch 35: val_loss improved from 0.19560 to 0.19498, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 994ms/step - loss: 0.1176 - val_loss: 0.1950
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - loss: 0.1154
# Epoch 36: val_loss improved from 0.19498 to 0.19482, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 976ms/step - loss: 0.1156 - val_loss: 0.1948
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - loss: 0.1151
# Epoch 37: val_loss did not improve from 0.19482
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 643ms/step - loss: 0.1152 - val_loss: 0.1950
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - loss: 0.1145
# Epoch 38: val_loss did not improve from 0.19482
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 645ms/step - loss: 0.1145 - val_loss: 0.1956
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - loss: 0.1129
# Epoch 39: val_loss did not improve from 0.19482
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 646ms/step - loss: 0.1129 - val_loss: 0.1954
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - loss: 0.1098
# Epoch 40: val_loss did not improve from 0.19482
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 634ms/step - loss: 0.1099 - val_loss: 0.1955
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - loss: 0.1101
# Epoch 41: val_loss improved from 0.19482 to 0.19474, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 983ms/step - loss: 0.1101 - val_loss: 0.1947
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - loss: 0.1093
# Epoch 42: val_loss improved from 0.19474 to 0.19447, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 980ms/step - loss: 0.1093 - val_loss: 0.1945
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - loss: 0.1074
# Epoch 43: val_loss improved from 0.19447 to 0.19386, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 995ms/step - loss: 0.1074 - val_loss: 0.1939
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - loss: 0.1072
# Epoch 44: val_loss improved from 0.19386 to 0.19347, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 983ms/step - loss: 0.1072 - val_loss: 0.1935
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - loss: 0.1051
# Epoch 45: val_loss improved from 0.19347 to 0.19254, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 968ms/step - loss: 0.1051 - val_loss: 0.1925
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - loss: 0.1029
# Epoch 46: val_loss did not improve from 0.19254
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 647ms/step - loss: 0.1030 - val_loss: 0.1930
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - loss: 0.1028
# Epoch 47: val_loss did not improve from 0.19254
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 648ms/step - loss: 0.1028 - val_loss: 0.1929
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - loss: 0.1017
# Epoch 48: val_loss did not improve from 0.19254
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 652ms/step - loss: 0.1017 - val_loss: 0.1928
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - loss: 0.0997
# Epoch 49: val_loss improved from 0.19254 to 0.19232, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 967ms/step - loss: 0.0997 - val_loss: 0.1923
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - loss: 0.0995
# Epoch 50: val_loss improved from 0.19232 to 0.19023, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 989ms/step - loss: 0.0995 - val_loss: 0.1902
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - loss: 0.0981
# Epoch 51: val_loss did not improve from 0.19023
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 650ms/step - loss: 0.0982 - val_loss: 0.1910
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - loss: 0.0966
# Epoch 52: val_loss improved from 0.19023 to 0.19011, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 977ms/step - loss: 0.0966 - val_loss: 0.1901
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - loss: 0.0965
# Epoch 53: val_loss did not improve from 0.19011
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 642ms/step - loss: 0.0965 - val_loss: 0.1902
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - loss: 0.0952
# Epoch 54: val_loss improved from 0.19011 to 0.18982, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 978ms/step - loss: 0.0952 - val_loss: 0.1898
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - loss: 0.0934
# Epoch 55: val_loss improved from 0.18982 to 0.18877, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 978ms/step - loss: 0.0935 - val_loss: 0.1888
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - loss: 0.0931
# Epoch 56: val_loss improved from 0.18877 to 0.18826, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 980ms/step - loss: 0.0932 - val_loss: 0.1883
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - loss: 0.0932
# Epoch 57: val_loss improved from 0.18826 to 0.18784, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 981ms/step - loss: 0.0932 - val_loss: 0.1878
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - loss: 0.0916
# Epoch 58: val_loss improved from 0.18784 to 0.18703, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 981ms/step - loss: 0.0916 - val_loss: 0.1870
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - loss: 0.0903
# Epoch 59: val_loss did not improve from 0.18703
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 651ms/step - loss: 0.0903 - val_loss: 0.1878
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - loss: 0.0887
# Epoch 60: val_loss improved from 0.18703 to 0.18693, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 979ms/step - loss: 0.0888 - val_loss: 0.1869
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - loss: 0.0871
# Epoch 61: val_loss improved from 0.18693 to 0.18637, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 966ms/step - loss: 0.0872 - val_loss: 0.1864
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - loss: 0.0865
# Epoch 62: val_loss improved from 0.18637 to 0.18614, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 984ms/step - loss: 0.0865 - val_loss: 0.1861
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - loss: 0.0859
# Epoch 63: val_loss improved from 0.18614 to 0.18324, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 980ms/step - loss: 0.0860 - val_loss: 0.1832
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - loss: 0.0852
# Epoch 64: val_loss did not improve from 0.18324
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 647ms/step - loss: 0.0852 - val_loss: 0.1847
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - loss: 0.0847
# Epoch 65: val_loss improved from 0.18324 to 0.18298, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 978ms/step - loss: 0.0846 - val_loss: 0.1830
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - loss: 0.0827
# Epoch 66: val_loss did not improve from 0.18298
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 646ms/step - loss: 0.0828 - val_loss: 0.1833
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - loss: 0.0833
# Epoch 67: val_loss improved from 0.18298 to 0.17972, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 977ms/step - loss: 0.0833 - val_loss: 0.1797
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - loss: 0.0820
# Epoch 68: val_loss did not improve from 0.17972
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 648ms/step - loss: 0.0820 - val_loss: 0.1814
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - loss: 0.0812
# Epoch 69: val_loss did not improve from 0.17972
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 644ms/step - loss: 0.0812 - val_loss: 0.1803
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - loss: 0.0803
# Epoch 70: val_loss did not improve from 0.17972
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 638ms/step - loss: 0.0804 - val_loss: 0.1811
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - loss: 0.0790
# Epoch 71: val_loss improved from 0.17972 to 0.17756, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 971ms/step - loss: 0.0791 - val_loss: 0.1776
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - loss: 0.0782
# Epoch 72: val_loss did not improve from 0.17756
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 638ms/step - loss: 0.0782 - val_loss: 0.1792
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - loss: 0.0773
# Epoch 73: val_loss did not improve from 0.17756
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 644ms/step - loss: 0.0774 - val_loss: 0.1789
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - loss: 0.0752
# Epoch 74: val_loss did not improve from 0.17756
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 649ms/step - loss: 0.0753 - val_loss: 0.1782
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - loss: 0.0734
# Epoch 75: val_loss improved from 0.17756 to 0.17459, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 981ms/step - loss: 0.0736 - val_loss: 0.1746
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - loss: 0.0737
# Epoch 76: val_loss did not improve from 0.17459
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 642ms/step - loss: 0.0737 - val_loss: 0.1751
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - loss: 0.0726
# Epoch 77: val_loss improved from 0.17459 to 0.17286, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 981ms/step - loss: 0.0727 - val_loss: 0.1729
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 527ms/step - loss: 0.0720
# Epoch 78: val_loss improved from 0.17286 to 0.16903, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 983ms/step - loss: 0.0721 - val_loss: 0.1690
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - loss: 0.0718
# Epoch 79: val_loss did not improve from 0.16903
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 646ms/step - loss: 0.0718 - val_loss: 0.1716
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - loss: 0.0717
# Epoch 80: val_loss improved from 0.16903 to 0.16582, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 987ms/step - loss: 0.0717 - val_loss: 0.1658
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - loss: 0.0701
# Epoch 81: val_loss improved from 0.16582 to 0.16542, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 981ms/step - loss: 0.0702 - val_loss: 0.1654
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - loss: 0.0687
# Epoch 82: val_loss improved from 0.16542 to 0.16434, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 969ms/step - loss: 0.0687 - val_loss: 0.1643
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 526ms/step - loss: 0.0680
# Epoch 83: val_loss improved from 0.16434 to 0.16113, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 984ms/step - loss: 0.0681 - val_loss: 0.1611
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - loss: 0.0679
# Epoch 84: val_loss improved from 0.16113 to 0.15872, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 952ms/step - loss: 0.0679 - val_loss: 0.1587
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 526ms/step - loss: 0.0667
# Epoch 85: val_loss did not improve from 0.15872
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 651ms/step - loss: 0.0667 - val_loss: 0.1647
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - loss: 0.0664
# Epoch 86: val_loss did not improve from 0.15872
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 652ms/step - loss: 0.0664 - val_loss: 0.1604
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - loss: 0.0656
# Epoch 87: val_loss did not improve from 0.15872
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 648ms/step - loss: 0.0657 - val_loss: 0.1588
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - loss: 0.0648
# Epoch 88: val_loss did not improve from 0.15872
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 633ms/step - loss: 0.0649 - val_loss: 0.1663
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - loss: 0.0650
# Epoch 89: val_loss improved from 0.15872 to 0.15151, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 977ms/step - loss: 0.0650 - val_loss: 0.1515
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - loss: 0.0627
# Epoch 90: val_loss did not improve from 0.15151
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 656ms/step - loss: 0.0628 - val_loss: 0.1556
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - loss: 0.0619
# Epoch 91: val_loss did not improve from 0.15151
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 645ms/step - loss: 0.0620 - val_loss: 0.1592
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - loss: 0.0613
# Epoch 92: val_loss improved from 0.15151 to 0.14839, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 974ms/step - loss: 0.0614 - val_loss: 0.1484
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - loss: 0.0610
# Epoch 93: val_loss did not improve from 0.14839
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 649ms/step - loss: 0.0611 - val_loss: 0.1627
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - loss: 0.0596
# Epoch 94: val_loss did not improve from 0.14839
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 646ms/step - loss: 0.0597 - val_loss: 0.1512
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 526ms/step - loss: 0.0590
# Epoch 95: val_loss did not improve from 0.14839
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 650ms/step - loss: 0.0590 - val_loss: 0.1484
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - loss: 0.0579
# Epoch 96: val_loss did not improve from 0.14839
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 642ms/step - loss: 0.0579 - val_loss: 0.1531
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - loss: 0.0575
# Epoch 97: val_loss did not improve from 0.14839
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 633ms/step - loss: 0.0575 - val_loss: 0.1510
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - loss: 0.0567
# Epoch 98: val_loss did not improve from 0.14839
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 650ms/step - loss: 0.0567 - val_loss: 0.1495
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - loss: 0.0550
# Epoch 99: val_loss did not improve from 0.14839
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 650ms/step - loss: 0.0551 - val_loss: 0.1488
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - loss: 0.0542
# Epoch 100: val_loss improved from 0.14839 to 0.14817, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - test_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 977ms/step - loss: 0.0543 - val_loss: 0.1482
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇███</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▆▅▄▄▄▃▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_loss</td><td>█▅▄▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>99</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>0.05505</td></tr><tr><td>epoch/val_loss</td><td>0.14817</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fresh-morning-49</strong> at: <a href='https://wandb.ai/itu-aml-project/itu-aml-project/runs/2ph5jyzg' target="_blank">https://wandb.ai/itu-aml-project/itu-aml-project/runs/2ph5jyzg</a><br/> View project at: <a href='https://wandb.ai/itu-aml-project/itu-aml-project' target="_blank">https://wandb.ai/itu-aml-project/itu-aml-project</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241203_120451-2ph5jyzg/logs</code>

# %%
# plot the training history
plot_history(comment=config.comment, history=history)
# Out:
# Best train_loss: 0.0551
# Best val_loss: 0.1482
# Last improvement of val_loss at epoch: 1

# %%
plot_reconstructions(autoencoder, test_generator, n_images=5, title='Test')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step

# %%
# sampling generated from flow
evaluate_autoencoder_with_threshold_generator(
    autoencoder=autoencoder,
    test_generator=test_generator,
    threshold_generator=threshold_generator,
    config=config
)
# Out:
# Optimal Threshold: 0.1514
#               precision    recall  f1-score   support
#
#       Normal       0.30      0.56      0.39        25
#      Anomaly       0.79      0.56      0.66        73
#
#     accuracy                           0.56        98
#    macro avg       0.55      0.56      0.53        98
# weighted avg       0.66      0.56      0.59        98

# %%
#without threshhold setting via distribution
import importlib
import utils.evaluation

# Reload the module to get updated functions
importlib.reload(utils.evaluation)
from utils.evaluation import evaluate_autoencoder
evaluate_autoencoder(
    config = config,
    autoencoder=autoencoder,
    validation_generator=validation_generator,
    test_generator=test_generator
    )
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.30      0.76      0.43        25
#      Anomaly       0.83      0.40      0.54        73
#
#     accuracy                           0.49        98
#    macro avg       0.57      0.58      0.48        98
# weighted avg       0.69      0.49      0.51        98

# %%
plot_latent_space(autoencoder, test_generator, layer_name='bottleneck')

# %%
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np

def preprocess_image(image_path, target_size=(256, 256)):
    """Load and preprocess an image for the autoencoder."""
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, target_size)
    img = img.astype('float32') / 255.0  # Normalize to [0, 1] and set to float32
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    return img

def calculate_reconstruction_error(original, reconstructed):
    """Calculate the mean squared error between original and reconstructed images."""
    return np.mean((original - reconstructed) ** 2)

def predict_anomaly_and_plot(autoencoder, image_path, mask_dir, threshold=0.02):
    """
    Predict if an image is an anomaly based on reconstruction error
    and plot original, reconstructed, and mask images.
    
    Parameters:
        autoencoder (Model): The trained autoencoder model.
        image_path (str): Path to the image file.
        mask_dir (str): Directory containing anomaly mask images.
        threshold (float): Error threshold to classify as anomaly.
    
    Returns:
        bool: True if anomaly, False otherwise.
        float: The reconstruction error.
    """
    # Preprocess the image
    img = preprocess_image(image_path)
    
    # Reconstruct the image with the autoencoder
    reconstructed_img = autoencoder.predict(img)

    # Ensure reconstructed image is in float32 format
    reconstructed_img = reconstructed_img.astype('float32')
    
    # Calculate reconstruction error
    error = calculate_reconstruction_error(img, reconstructed_img)
    
    # Classify as anomaly if error exceeds the threshold
    is_anomaly = error > threshold

    # Generate the corresponding mask path
    file_name = os.path.basename(image_path).split('.')[0] + '_mask.png'
    label = os.path.basename(os.path.dirname(image_path))
    mask_path = os.path.join(mask_dir, label, file_name)
    
    # Load the mask image if it exists
    if os.path.exists(mask_path):
        mask_img = plt.imread(mask_path)
    else:
        mask_img = None

    # Plot original, reconstructed, and mask images
    plt.figure(figsize=(12, 4))
    
    # Original image
    plt.subplot(1, 3, 1)
    plt.imshow(img[0])  # Remove batch dimension for display
    plt.title("Original Image")
    plt.axis("off")
    
    # Reconstructed image
    plt.subplot(1, 3, 2)
    plt.imshow(reconstructed_img[0])  # Remove batch dimension for display
    plt.title("Reconstructed Image")
    plt.axis("off")
    
    # Anomaly mask
    plt.subplot(1, 3, 3)
    if mask_img is not None:
        plt.imshow(mask_img, cmap="gray")
        plt.title("Anomaly Mask")
    else:
        plt.text(0.5, 0.5, 'No Mask Available', ha='center', va='center', fontsize=12)
    plt.axis("off")
    
    plt.suptitle(f"Reconstruction Error: {error:.4f}| Threshold: {threshold} | Anomaly: {'Yes' if is_anomaly else 'No'}")
    plt.show()
    
    return is_anomaly, error

# Example usage
# Example usage
mask_dir = '../../data/screw/ground_truth'
image_paths = [
    '../../data/screw/test/manipulated_front/001.png',
    '../../data/screw/test/scratch_head/001.png', 
    '../../data/screw/test/scratch_neck/001.png' 
]
'''
mask_dir = 'data/screw/ground_truth'
image_paths = [
    'data/screw/test/manipulated_front/001.png',
    'data/screw/test/scratch_head/001.png', 
    'data/screw/test/scratch_neck/001.png' 
]
'''
for path in image_paths: 
    is_anomaly, error = predict_anomaly_and_plot(autoencoder, path, mask_dir)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step

# %%
importlib.reload(utils.evaluation)

from utils.evaluation import evaluate_autoencoder, ssim_loss, ssim_l1_loss, dssim_loss, evaluate_autoencoder_with_distribution_threshold, evaluate_autoencoder_with_threshold_generator
