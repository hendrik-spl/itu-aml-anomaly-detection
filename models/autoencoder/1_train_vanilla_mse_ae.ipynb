# %%
import os
import sys

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose, LeakyReLU, BatchNormalization, Flatten, Dense, Reshape, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import wandb
from wandb.integration.keras import WandbMetricsLogger, WandbModelCheckpoint

# modify sys.path for it to contain the main repo path so we can import modules such as below
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '../..'))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

from utils.helper import get_root_dir, set_seed, setup_gpu
from utils.data import load_data_with_test_split
from utils.plots import plot_reconstructions, plot_history
from utils.latent_space import plot_latent_space
from utils.evaluation import evaluate_autoencoder, ssim_loss, ssim_l1_loss, dssim_loss, evaluate_autoencoder_with_distribution_threshold, evaluate_autoencoder_with_threshold_generator

# %%
# Hyperparameter to tune
config = {
    "comment" : "test test",
    "epochs" : 100,
    "loss" : 'mse',
    "optimizer" : "adam",
    "dropout": True,
    "dropout_value" : 0.0,
    "rotation_range" : 90,
    "batch_size" : 16,
    "latent_dim" : 512,
    "threshold_percentage" : 80,
    "data_class" : "screw",
    "model_type" : "autoencoder"
}

# Rather static parameters, no need to track
IMAGE_SIZE = (256, 256)
INPUT_SHAPE = IMAGE_SIZE + (3,)

# %%
wandb.init(project="itu-aml-project", config=config)
config = wandb.config # this turns our hyperparameter config into a proper object with attributes
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: hendrik-spl (itu-aml-project). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>/Users/hendriksippel/Documents/Repositories/itu-aml-anomaly-detection/models/autoencoder/wandb/run-20241210_115908-k689o81a</code>
# Syncing run <strong><a href='https://wandb.ai/itu-aml-project/itu-aml-project/runs/k689o81a' target="_blank">olive-plasma-65</a></strong> to <a href='https://wandb.ai/itu-aml-project/itu-aml-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/itu-aml-project/itu-aml-project' target="_blank">https://wandb.ai/itu-aml-project/itu-aml-project</a>
#  View run at <a href='https://wandb.ai/itu-aml-project/itu-aml-project/runs/k689o81a' target="_blank">https://wandb.ai/itu-aml-project/itu-aml-project/runs/k689o81a</a>

# %%
root_dir = get_root_dir()
# root_dir = 'Mini Project'

set_seed(1234)

model_dir = os.path.join(root_dir, 'models', config.model_type)

cpkt_path = os.path.join(model_dir, 'logs', 'checkpoints', f'{config.comment}_checkpoint.model.keras')
weights_path = os.path.join(model_dir, 'logs', 'weights', f'{config.comment}_model.keras')
assert not os.path.exists(weights_path), f'Path already exists: {weights_path}. Please change the comment.'

# %%
train_generator, validation_generator, test_generator, threshold_generator = load_data_with_test_split(
    category="screw",
    batch_size=32,
    test_split=0.4,
    rotation_range=config.rotation_range
)
# Out:
# Found 256 images belonging to 1 classes.
# Found 64 images belonging to 1 classes.
# Found 98 images belonging to 6 classes.
# Found 62 images belonging to 6 classes.

# %%
def vanilla_autoencoder(input_shape=INPUT_SHAPE, optimizer='', latent_dim=512, loss='mse'):
    """
        input_shape (tuple): Shape of the input images (height, width, channels).
        latent_dim (int): Dimension of the latent space.
        loss (str): Loss used to train the autoencoder. Options: 'mse', 'ssim', etc.
    """
    # Encoder
    input_img = Input(shape=input_shape)

    # Encoder with reduced complexity
    x = Conv2D(32, (3, 3), padding='same')(input_img)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = MaxPooling2D((2, 2), padding='same')(x)  # (128, 128, 32)
    x = Dropout(0.3)(x)

    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = MaxPooling2D((2, 2), padding='same')(x)  # (64, 64, 64)
    x = Dropout(0.3)(x)

    x = Conv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)
    x = MaxPooling2D((2, 2), padding='same')(x)  # (32, 32, 128)
    x = Dropout(0.3)(x)

    # Bottleneck
    x = Flatten()(x)  # Flattened Shape: (32 * 32 * 128,)
    encoded = Dense(latent_dim)(x)  # Latent space size reduced to 526
    encoded = BatchNormalization()(encoded)
    encoded = LeakyReLU(name='bottleneck')(encoded)

    # Decoder with reduced complexity
    x = Dense(32 * 32 * 128)(encoded)
    x = Reshape((32, 32, 128))(x)

    x = UpSampling2D((2, 2))(x)  # (64, 64, 128)
    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = UpSampling2D((2, 2))(x)  # (128, 128, 64)
    x = Conv2D(32, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = UpSampling2D((2, 2))(x)  # (256, 256, 32)
    x = Conv2D(input_shape[2], (3, 3), activation='sigmoid', padding='same')(x)

    # Autoencoder Model
    autoencoder = Model(input_img, x)
    autoencoder.compile(optimizer=optimizer, loss=loss)
    return autoencoder

# get correct loss from config as functions are not callable from config itself
if config.loss == 'mae': loss = 'mae'
elif config.loss == 'mse': loss = 'mse'
elif config.loss == 'dssim_loss': loss = dssim_loss
elif config.loss == 'ssim_loss': loss = ssim_loss
elif config.loss == 'ssim_l1_loss': loss = ssim_l1_loss
else:
    raise ValueError(f"Unknown loss function: {config.loss}. Please define a function to calculate the error.")

print(f"Used Loss to train:{loss}")
print(f"Optimizer: {config.optimizer}")

autoencoder = vanilla_autoencoder(
    input_shape=INPUT_SHAPE, 
    optimizer=config.optimizer, 
    latent_dim=config.latent_dim, 
    loss=loss
)

print("Input shape:", autoencoder.input_shape)
print("Output shape:", autoencoder.output_shape)

autoencoder.summary()
# Out:
# Used Loss to train:mse
# Optimizer: adam
# Input shape: (None, 256, 256, 3)
# Output shape: (None, 256, 256, 3)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256, 256, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 256, 256, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 128, 128, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128, 128, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 131072)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    67,109,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bottleneck (LeakyReLU)          │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 131072)         │    67,239,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 64, 64, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 128, 128, 32)   │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_2 (UpSampling2D)  │ (None, 256, 256, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 256, 256, 3)    │           867 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 134,539,011 (513.23 MB)
#  Trainable params: 134,537,347 (513.22 MB)
#  Non-trainable params: 1,664 (6.50 KB)

# %%
#define early stopping and checkpoints
early_stop = EarlyStopping(
    monitor="val_loss", 
    mode="min",
    patience=20, 
    start_from_epoch=20
    )

checkpoint = ModelCheckpoint(
    cpkt_path, 
    monitor="val_loss", 
    mode="min", 
    save_best_only=True, 
    verbose=1
    )

history = autoencoder.fit(
    train_generator,
    epochs=config.epochs,
    validation_data=validation_generator,
    callbacks=[
        early_stop,
        checkpoint,
        WandbMetricsLogger(),
        # WandbModelCheckpoint("models"), # Saves model checkpoint to W&B
    ],
)

wandb.finish()
# Out:
# /opt/conda/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - loss: 0.0924
# Epoch 1: val_loss improved from inf to 0.03399, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - loss: 0.0892 - val_loss: 0.0340
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - loss: 0.0181
# Epoch 2: val_loss improved from 0.03399 to 0.02522, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 941ms/step - loss: 0.0177 - val_loss: 0.0252
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - loss: 0.0081
# Epoch 3: val_loss improved from 0.02522 to 0.01894, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 945ms/step - loss: 0.0080 - val_loss: 0.0189
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - loss: 0.0058
# Epoch 4: val_loss did not improve from 0.01894
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 630ms/step - loss: 0.0057 - val_loss: 0.0261
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - loss: 0.0041
# Epoch 5: val_loss did not improve from 0.01894
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 628ms/step - loss: 0.0040 - val_loss: 0.0289
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - loss: 0.0031
# Epoch 6: val_loss did not improve from 0.01894
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 637ms/step - loss: 0.0031 - val_loss: 0.0328
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - loss: 0.0027
# Epoch 7: val_loss did not improve from 0.01894
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 636ms/step - loss: 0.0027 - val_loss: 0.0311
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - loss: 0.0024
# Epoch 8: val_loss did not improve from 0.01894
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 624ms/step - loss: 0.0024 - val_loss: 0.0291
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - loss: 0.0022
# Epoch 9: val_loss did not improve from 0.01894
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 631ms/step - loss: 0.0022 - val_loss: 0.0269
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - loss: 0.0021
# Epoch 10: val_loss did not improve from 0.01894
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 642ms/step - loss: 0.0021 - val_loss: 0.0274
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - loss: 0.0020
# Epoch 11: val_loss did not improve from 0.01894
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 637ms/step - loss: 0.0020 - val_loss: 0.0245
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - loss: 0.0019
# Epoch 12: val_loss did not improve from 0.01894
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 630ms/step - loss: 0.0019 - val_loss: 0.0242
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - loss: 0.0018
# Epoch 13: val_loss did not improve from 0.01894
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 633ms/step - loss: 0.0018 - val_loss: 0.0234
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - loss: 0.0018
# Epoch 14: val_loss did not improve from 0.01894
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 633ms/step - loss: 0.0018 - val_loss: 0.0234
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - loss: 0.0017
# Epoch 15: val_loss did not improve from 0.01894
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 632ms/step - loss: 0.0017 - val_loss: 0.0216
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - loss: 0.0016
# Epoch 16: val_loss did not improve from 0.01894
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 642ms/step - loss: 0.0016 - val_loss: 0.0216
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - loss: 0.0016
# Epoch 17: val_loss did not improve from 0.01894
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 633ms/step - loss: 0.0016 - val_loss: 0.0214
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - loss: 0.0016
# Epoch 18: val_loss did not improve from 0.01894
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 634ms/step - loss: 0.0016 - val_loss: 0.0207
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - loss: 0.0015
# Epoch 19: val_loss did not improve from 0.01894
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 625ms/step - loss: 0.0015 - val_loss: 0.0203
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - loss: 0.0015
# Epoch 20: val_loss did not improve from 0.01894
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 635ms/step - loss: 0.0015 - val_loss: 0.0197
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - loss: 0.0015
# Epoch 21: val_loss did not improve from 0.01894
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 631ms/step - loss: 0.0015 - val_loss: 0.0199
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - loss: 0.0015
# Epoch 22: val_loss did not improve from 0.01894
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 626ms/step - loss: 0.0015 - val_loss: 0.0190
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - loss: 0.0015
# Epoch 23: val_loss improved from 0.01894 to 0.01875, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 968ms/step - loss: 0.0015 - val_loss: 0.0187
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - loss: 0.0015
# Epoch 24: val_loss improved from 0.01875 to 0.01847, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 968ms/step - loss: 0.0015 - val_loss: 0.0185
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - loss: 0.0014
# Epoch 25: val_loss improved from 0.01847 to 0.01839, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 957ms/step - loss: 0.0014 - val_loss: 0.0184
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - loss: 0.0014
# Epoch 26: val_loss improved from 0.01839 to 0.01776, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 950ms/step - loss: 0.0014 - val_loss: 0.0178
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - loss: 0.0014
# Epoch 27: val_loss improved from 0.01776 to 0.01761, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 966ms/step - loss: 0.0014 - val_loss: 0.0176
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - loss: 0.0013
# Epoch 28: val_loss improved from 0.01761 to 0.01756, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 970ms/step - loss: 0.0013 - val_loss: 0.0176
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - loss: 0.0013
# Epoch 29: val_loss improved from 0.01756 to 0.01713, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 963ms/step - loss: 0.0014 - val_loss: 0.0171
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - loss: 0.0013
# Epoch 30: val_loss improved from 0.01713 to 0.01702, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 965ms/step - loss: 0.0013 - val_loss: 0.0170
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - loss: 0.0013
# Epoch 31: val_loss improved from 0.01702 to 0.01631, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 969ms/step - loss: 0.0013 - val_loss: 0.0163
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - loss: 0.0013
# Epoch 32: val_loss improved from 0.01631 to 0.01623, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 964ms/step - loss: 0.0013 - val_loss: 0.0162
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - loss: 0.0013
# Epoch 33: val_loss improved from 0.01623 to 0.01594, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 960ms/step - loss: 0.0013 - val_loss: 0.0159
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - loss: 0.0012
# Epoch 34: val_loss did not improve from 0.01594
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 638ms/step - loss: 0.0012 - val_loss: 0.0161
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - loss: 0.0012
# Epoch 35: val_loss improved from 0.01594 to 0.01551, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 972ms/step - loss: 0.0012 - val_loss: 0.0155
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - loss: 0.0012
# Epoch 36: val_loss did not improve from 0.01551
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 621ms/step - loss: 0.0013 - val_loss: 0.0156
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - loss: 0.0012
# Epoch 37: val_loss improved from 0.01551 to 0.01551, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 969ms/step - loss: 0.0012 - val_loss: 0.0155
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - loss: 0.0012
# Epoch 38: val_loss improved from 0.01551 to 0.01533, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 958ms/step - loss: 0.0012 - val_loss: 0.0153
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - loss: 0.0011
# Epoch 39: val_loss improved from 0.01533 to 0.01501, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 959ms/step - loss: 0.0011 - val_loss: 0.0150
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - loss: 0.0011
# Epoch 40: val_loss improved from 0.01501 to 0.01490, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 968ms/step - loss: 0.0011 - val_loss: 0.0149
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - loss: 0.0012
# Epoch 41: val_loss did not improve from 0.01490
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 629ms/step - loss: 0.0012 - val_loss: 0.0151
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - loss: 0.0012
# Epoch 42: val_loss improved from 0.01490 to 0.01429, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 944ms/step - loss: 0.0012 - val_loss: 0.0143
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - loss: 0.0012
# Epoch 43: val_loss did not improve from 0.01429
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 633ms/step - loss: 0.0012 - val_loss: 0.0150
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - loss: 0.0011
# Epoch 44: val_loss improved from 0.01429 to 0.01418, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 958ms/step - loss: 0.0012 - val_loss: 0.0142
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - loss: 0.0011
# Epoch 45: val_loss did not improve from 0.01418
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 619ms/step - loss: 0.0011 - val_loss: 0.0144
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - loss: 0.0011
# Epoch 46: val_loss did not improve from 0.01418
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 631ms/step - loss: 0.0011 - val_loss: 0.0142
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - loss: 0.0011
# Epoch 47: val_loss improved from 0.01418 to 0.01394, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 958ms/step - loss: 0.0011 - val_loss: 0.0139
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - loss: 0.0011
# Epoch 48: val_loss improved from 0.01394 to 0.01377, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 960ms/step - loss: 0.0011 - val_loss: 0.0138
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - loss: 0.0010
# Epoch 49: val_loss improved from 0.01377 to 0.01351, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 959ms/step - loss: 0.0010 - val_loss: 0.0135
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - loss: 0.0010
# Epoch 50: val_loss improved from 0.01351 to 0.01281, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 970ms/step - loss: 0.0011 - val_loss: 0.0128
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - loss: 0.0010
# Epoch 51: val_loss did not improve from 0.01281
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 632ms/step - loss: 0.0010 - val_loss: 0.0131
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - loss: 0.0010
# Epoch 52: val_loss improved from 0.01281 to 0.01265, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 958ms/step - loss: 0.0010 - val_loss: 0.0126
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - loss: 0.0010
# Epoch 53: val_loss improved from 0.01265 to 0.01218, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 973ms/step - loss: 0.0010 - val_loss: 0.0122
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - loss: 0.0010
# Epoch 54: val_loss did not improve from 0.01218
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 634ms/step - loss: 0.0010 - val_loss: 0.0129
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - loss: 9.7677e-04
# Epoch 55: val_loss did not improve from 0.01218
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 643ms/step - loss: 9.8327e-04 - val_loss: 0.0128
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - loss: 0.0010
# Epoch 56: val_loss improved from 0.01218 to 0.01205, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 959ms/step - loss: 0.0010 - val_loss: 0.0121
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - loss: 0.0010
# Epoch 57: val_loss improved from 0.01205 to 0.01132, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 967ms/step - loss: 0.0010 - val_loss: 0.0113
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - loss: 0.0010
# Epoch 58: val_loss did not improve from 0.01132
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 632ms/step - loss: 0.0010 - val_loss: 0.0117
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - loss: 9.6857e-04
# Epoch 59: val_loss did not improve from 0.01132
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 648ms/step - loss: 9.6859e-04 - val_loss: 0.0118
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - loss: 9.4980e-04
# Epoch 60: val_loss improved from 0.01132 to 0.01115, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 951ms/step - loss: 9.5182e-04 - val_loss: 0.0112
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - loss: 9.2659e-04
# Epoch 61: val_loss did not improve from 0.01115
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 629ms/step - loss: 9.2889e-04 - val_loss: 0.0113
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - loss: 9.1474e-04
# Epoch 62: val_loss did not improve from 0.01115
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 636ms/step - loss: 9.1572e-04 - val_loss: 0.0112
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - loss: 8.9613e-04
# Epoch 63: val_loss improved from 0.01115 to 0.01100, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 956ms/step - loss: 8.9807e-04 - val_loss: 0.0110
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - loss: 9.0540e-04
# Epoch 64: val_loss did not improve from 0.01100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 632ms/step - loss: 9.0703e-04 - val_loss: 0.0114
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - loss: 9.0022e-04
# Epoch 65: val_loss improved from 0.01100 to 0.01060, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 965ms/step - loss: 9.0326e-04 - val_loss: 0.0106
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - loss: 8.8746e-04
# Epoch 66: val_loss did not improve from 0.01060
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 639ms/step - loss: 8.9149e-04 - val_loss: 0.0113
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - loss: 9.2156e-04
# Epoch 67: val_loss improved from 0.01060 to 0.00927, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 964ms/step - loss: 9.2345e-04 - val_loss: 0.0093
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - loss: 9.0669e-04
# Epoch 68: val_loss did not improve from 0.00927
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 628ms/step - loss: 9.0585e-04 - val_loss: 0.0100
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - loss: 8.6857e-04
# Epoch 69: val_loss did not improve from 0.00927
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 642ms/step - loss: 8.7014e-04 - val_loss: 0.0099
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - loss: 8.7353e-04
# Epoch 70: val_loss did not improve from 0.00927
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 631ms/step - loss: 8.7590e-04 - val_loss: 0.0097
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - loss: 8.5968e-04
# Epoch 71: val_loss did not improve from 0.00927
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 622ms/step - loss: 8.6232e-04 - val_loss: 0.0095
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - loss: 8.2566e-04
# Epoch 72: val_loss improved from 0.00927 to 0.00892, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 966ms/step - loss: 8.2838e-04 - val_loss: 0.0089
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - loss: 8.2582e-04
# Epoch 73: val_loss improved from 0.00892 to 0.00881, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 958ms/step - loss: 8.2894e-04 - val_loss: 0.0088
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - loss: 7.9281e-04
# Epoch 74: val_loss did not improve from 0.00881
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 631ms/step - loss: 7.9482e-04 - val_loss: 0.0088
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - loss: 7.7405e-04
# Epoch 75: val_loss did not improve from 0.00881
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 632ms/step - loss: 7.7559e-04 - val_loss: 0.0089
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - loss: 8.0553e-04
# Epoch 76: val_loss improved from 0.00881 to 0.00813, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 954ms/step - loss: 8.0632e-04 - val_loss: 0.0081
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - loss: 7.8354e-04
# Epoch 77: val_loss did not improve from 0.00813
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 642ms/step - loss: 7.8717e-04 - val_loss: 0.0085
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - loss: 7.7398e-04
# Epoch 78: val_loss improved from 0.00813 to 0.00739, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 963ms/step - loss: 7.7549e-04 - val_loss: 0.0074
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - loss: 7.7826e-04
# Epoch 79: val_loss did not improve from 0.00739
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 641ms/step - loss: 7.8033e-04 - val_loss: 0.0077
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - loss: 7.5798e-04
# Epoch 80: val_loss did not improve from 0.00739
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 641ms/step - loss: 7.6157e-04 - val_loss: 0.0076
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - loss: 7.4579e-04
# Epoch 81: val_loss improved from 0.00739 to 0.00690, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 958ms/step - loss: 7.4622e-04 - val_loss: 0.0069
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - loss: 7.5033e-04
# Epoch 82: val_loss did not improve from 0.00690
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 647ms/step - loss: 7.5201e-04 - val_loss: 0.0075
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - loss: 7.4525e-04
# Epoch 83: val_loss improved from 0.00690 to 0.00618, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 954ms/step - loss: 7.4958e-04 - val_loss: 0.0062
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - loss: 7.2355e-04
# Epoch 84: val_loss did not improve from 0.00618
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 643ms/step - loss: 7.2699e-04 - val_loss: 0.0068
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - loss: 7.2150e-04
# Epoch 85: val_loss did not improve from 0.00618
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 626ms/step - loss: 7.2520e-04 - val_loss: 0.0064
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - loss: 7.2607e-04
# Epoch 86: val_loss did not improve from 0.00618
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 629ms/step - loss: 7.2571e-04 - val_loss: 0.0070
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - loss: 7.0909e-04
# Epoch 87: val_loss did not improve from 0.00618
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 633ms/step - loss: 7.1086e-04 - val_loss: 0.0072
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - loss: 7.8857e-04
# Epoch 88: val_loss improved from 0.00618 to 0.00582, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 949ms/step - loss: 7.8908e-04 - val_loss: 0.0058
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - loss: 7.3178e-04
# Epoch 89: val_loss improved from 0.00582 to 0.00570, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 962ms/step - loss: 7.3312e-04 - val_loss: 0.0057
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - loss: 7.5582e-04
# Epoch 90: val_loss did not improve from 0.00570
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 634ms/step - loss: 7.5435e-04 - val_loss: 0.0065
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - loss: 7.4165e-04
# Epoch 91: val_loss did not improve from 0.00570
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 625ms/step - loss: 7.3962e-04 - val_loss: 0.0067
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - loss: 6.9550e-04
# Epoch 92: val_loss improved from 0.00570 to 0.00543, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 953ms/step - loss: 6.9712e-04 - val_loss: 0.0054
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - loss: 7.1368e-04
# Epoch 93: val_loss did not improve from 0.00543
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 641ms/step - loss: 7.1544e-04 - val_loss: 0.0060
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - loss: 6.6575e-04
# Epoch 94: val_loss improved from 0.00543 to 0.00528, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 966ms/step - loss: 6.6773e-04 - val_loss: 0.0053
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - loss: 6.4332e-04
# Epoch 95: val_loss did not improve from 0.00528
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 642ms/step - loss: 6.4306e-04 - val_loss: 0.0057
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - loss: 6.4594e-04
# Epoch 96: val_loss did not improve from 0.00528
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 640ms/step - loss: 6.4868e-04 - val_loss: 0.0060
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - loss: 6.4400e-04
# Epoch 97: val_loss did not improve from 0.00528
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 628ms/step - loss: 6.4474e-04 - val_loss: 0.0056
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - loss: 6.4951e-04
# Epoch 98: val_loss did not improve from 0.00528
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 640ms/step - loss: 6.5030e-04 - val_loss: 0.0066
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - loss: 6.2762e-04
# Epoch 99: val_loss improved from 0.00528 to 0.00522, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 959ms/step - loss: 6.2827e-04 - val_loss: 0.0052
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - loss: 6.2588e-04
# Epoch 100: val_loss improved from 0.00522 to 0.00473, saving model to Mini Project/models/autoencoder/logs/checkpoints/Vanilla AE - MSE_checkpoint.model.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 953ms/step - loss: 6.2717e-04 - val_loss: 0.0047
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>▁▁▁▁▁▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▆▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_loss</td><td>█▄█▆▆▅▅▅▄▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/epoch</td><td>99</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>0.00064</td></tr><tr><td>epoch/val_loss</td><td>0.00473</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">eager-energy-50</strong> at: <a href='https://wandb.ai/itu-aml-project/itu-aml-project/runs/ebh12x0n' target="_blank">https://wandb.ai/itu-aml-project/itu-aml-project/runs/ebh12x0n</a><br/> View project at: <a href='https://wandb.ai/itu-aml-project/itu-aml-project' target="_blank">https://wandb.ai/itu-aml-project/itu-aml-project</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241203_122141-ebh12x0n/logs</code>

# %%
# plot the training history
plot_history(comment=config.comment, history=history)
# Out:
# Best train_loss: 0.0006
# Best val_loss: 0.0047
# Last improvement of val_loss at epoch: 1

# %%
plot_reconstructions(autoencoder, test_generator, n_images=5, title='Test')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step

# %%
# sampling generated from flow
evaluate_autoencoder_with_threshold_generator(
    autoencoder=autoencoder,
    test_generator=test_generator,
    threshold_generator=threshold_generator,
    config=config
)
# Out:
# Optimal Threshold: 0.0046
#               precision    recall  f1-score   support
#
#       Normal       0.46      0.76      0.58        25
#      Anomaly       0.89      0.70      0.78        73
#
#     accuracy                           0.71        98
#    macro avg       0.68      0.73      0.68        98
# weighted avg       0.78      0.71      0.73        98

# %%
#without threshhold setting via distribution
import importlib
import utils.evaluation

# Reload the module to get updated functions
importlib.reload(utils.evaluation)
from utils.evaluation import evaluate_autoencoder
evaluate_autoencoder(
    config = config,
    autoencoder=autoencoder,
    validation_generator=validation_generator,
    test_generator=test_generator
    )
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.33      1.00      0.50        25
#      Anomaly       1.00      0.30      0.46        73
#
#     accuracy                           0.48        98
#    macro avg       0.66      0.65      0.48        98
# weighted avg       0.83      0.48      0.47        98

# %%
plot_latent_space(autoencoder, test_generator, layer_name='bottleneck')

# %%
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np

def preprocess_image(image_path, target_size=(256, 256)):
    """Load and preprocess an image for the autoencoder."""
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, target_size)
    img = img.astype('float32') / 255.0  # Normalize to [0, 1] and set to float32
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    return img

def calculate_reconstruction_error(original, reconstructed):
    """Calculate the mean squared error between original and reconstructed images."""
    return np.mean((original - reconstructed) ** 2)

def predict_anomaly_and_plot(autoencoder, image_path, mask_dir, threshold=0.02):
    """
    Predict if an image is an anomaly based on reconstruction error
    and plot original, reconstructed, and mask images.
    
    Parameters:
        autoencoder (Model): The trained autoencoder model.
        image_path (str): Path to the image file.
        mask_dir (str): Directory containing anomaly mask images.
        threshold (float): Error threshold to classify as anomaly.
    
    Returns:
        bool: True if anomaly, False otherwise.
        float: The reconstruction error.
    """
    # Preprocess the image
    img = preprocess_image(image_path)
    
    # Reconstruct the image with the autoencoder
    reconstructed_img = autoencoder.predict(img)

    # Ensure reconstructed image is in float32 format
    reconstructed_img = reconstructed_img.astype('float32')
    
    # Calculate reconstruction error
    error = calculate_reconstruction_error(img, reconstructed_img)
    
    # Classify as anomaly if error exceeds the threshold
    is_anomaly = error > threshold

    # Generate the corresponding mask path
    file_name = os.path.basename(image_path).split('.')[0] + '_mask.png'
    label = os.path.basename(os.path.dirname(image_path))
    mask_path = os.path.join(mask_dir, label, file_name)
    
    # Load the mask image if it exists
    if os.path.exists(mask_path):
        mask_img = plt.imread(mask_path)
    else:
        mask_img = None

    # Plot original, reconstructed, and mask images
    plt.figure(figsize=(12, 4))
    
    # Original image
    plt.subplot(1, 3, 1)
    plt.imshow(img[0])  # Remove batch dimension for display
    plt.title("Original Image")
    plt.axis("off")
    
    # Reconstructed image
    plt.subplot(1, 3, 2)
    plt.imshow(reconstructed_img[0])  # Remove batch dimension for display
    plt.title("Reconstructed Image")
    plt.axis("off")
    
    # Anomaly mask
    plt.subplot(1, 3, 3)
    if mask_img is not None:
        plt.imshow(mask_img, cmap="gray")
        plt.title("Anomaly Mask")
    else:
        plt.text(0.5, 0.5, 'No Mask Available', ha='center', va='center', fontsize=12)
    plt.axis("off")
    
    plt.suptitle(f"Reconstruction Error: {error:.4f}| Threshold: {threshold} | Anomaly: {'Yes' if is_anomaly else 'No'}")
    plt.show()
    
    return is_anomaly, error

# Example usage
# Example usage
"""mask_dir = '../../data/screw/ground_truth'
image_paths = [
    '../../data/screw/test/manipulated_front/001.png',
    '../../data/screw/test/scratch_head/001.png', 
    '../../data/screw/test/scratch_neck/001.png' 
]"""
mask_dir = 'data/screw/ground_truth'
image_paths = [
    'data/screw/test/manipulated_front/001.png',
    'data/screw/test/scratch_head/001.png', 
    'data/screw/test/scratch_neck/001.png' 
]
for path in image_paths: 
    is_anomaly, error = predict_anomaly_and_plot(autoencoder, path, mask_dir)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
